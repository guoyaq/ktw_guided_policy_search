# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
import model
import cost
import iLQR
import poliOpt
import trajOpt
import policyClass
import modelLearn
from gps_util import getCostNN, getCostAppNN, getCostTraj, getObs, getDesired
from gps_unicycle import mdGPS

# %%
myGPS = mdGPS('hi')
W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
# Out:
# initial trajectories from iLQR
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           120.8       95.1        95.1        1.07        0.0
# 1           25.6977     2.36e-09    2.32e-09    4.24e-06    -0.2
# SUCCEESS: cost change < tolFun
# ('sample generation cost = ', 221.08049607970983)
# ('sample generation cost = ', 183.08745511551513)
# ('sample generation cost = ', 234.19186584315167)
# ('sample generation cost = ', 216.21983487979037)
# ('sample generation cost = ', 219.80113287092715)
# ('sample generation cost = ', 200.53349794254208)
# ('sample generation cost = ', 210.05951950650348)
# ('sample generation cost = ', 204.58487215941085)
# ('sample generation cost = ', 214.15377909445397)
# ('sample generation cost = ', 203.03940860111052)
# ('sample generation cost = ', 203.97513738267287)
# ('sample generation cost = ', 190.02600909267758)
# ('sample generation cost = ', 218.42326461929682)
# ('sample generation cost = ', 247.68126144109573)
# ('sample generation cost = ', 220.22665140194039)
# ('sample generation cost = ', 182.83924394315318)
# ('sample generation cost = ', 172.563185140298)
# ('sample generation cost = ', 213.08535503279285)
# ('sample generation cost = ', 228.31396269260597)
# ('sample generation cost = ', 208.61998452258013)
# initial policy optimization starts!!
# 2.27514
# 2.03843
# 2.0346
# 2.03494
# 2.03778
# Optimization - policy mean is done
# Optimization - policy variance is done
# initial policy parameter is updated true cost is  10000.0
# ======================== Mirror descent GPS ============================
# iteration =  1
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 186.74179927
# mean value of real cost is 339.624940983
# mean value of real cost is 237.166917867
# mean value of real cost is 373.727428397
# mean value of real cost is 191.284432824
# mean value of real cost is 249.464517308
# mean value of real cost is 198.252755786
# mean value of real cost is 286.089656265
# mean value of real cost is 248.328198256
# mean value of real cost is 237.329829941
# mean value of real cost is 269.245606398
# mean value of real cost is 270.462389821
# mean value of real cost is 186.344892229
# mean value of real cost is 260.90207448
# mean value of real cost is 179.295089003
# mean value of real cost is 207.295744429
# mean value of real cost is 219.581620737
# mean value of real cost is 226.261326336
# mean value of real cost is 257.358222469
# mean value of real cost is 249.453827232
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 28.167496356490812, 'KL = ', 34.052624445453709, 'epsilon = ', 5)
# ('KL > epsilon // eta = ', 10.0)
# SUCCEESS: cost change < tolFun
# ('cost = ', 40.257132294868093, 'KL = ', 1.542649354696612, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS: cost change < tolFun
# ('cost = ', 32.374947359096673, 'KL = ', 7.715262894203228, 'epsilon = ', 5)
# ('KL > epsilon // eta = ', 5.6234132519034912)
# SUCCEESS: cost change < tolFun
# ('cost = ', 35.846727880922323, 'KL = ', 3.4759039456523162, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 4.2169650342858223)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 33.988986836752666, 'KL = ', 5.1880587746797335, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 4.2169650342858223)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 288.774336427
# mean value of real cost is 380.492355586
# mean value of real cost is 294.365021285
# mean value of real cost is 378.604894586
# mean value of real cost is 196.213551598
# mean value of real cost is 207.622802577
# mean value of real cost is 282.943199589
# mean value of real cost is 242.658499697
# mean value of real cost is 303.667535864
# mean value of real cost is 292.335062942
# mean value of real cost is 298.086777534
# mean value of real cost is 284.210651613
# mean value of real cost is 200.135069918
# mean value of real cost is 262.288389057
# mean value of real cost is 233.381892151
# mean value of real cost is 219.876595024
# mean value of real cost is 220.030527027
# mean value of real cost is 305.209301496
# mean value of real cost is 268.444394187
# mean value of real cost is 329.709107719
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 4.2169650342858223)
# SUCCEESS: cost change < tolFun
# ('cost = ', 47.088144071425155, 'KL = ', 6.032107437578766, 'epsilon = ', 5)
# ('KL > epsilon // eta = ', 42.169650342858219)
# SUCCEESS: cost change < tolFun
# ('cost = ', 75.571851654756586, 'KL = ', 0.29368480300280625, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 13.33521432163324)
# SUCCEESS: cost change < tolFun
# ('cost = ', 59.888807987709328, 'KL = ', 1.3702595019205734, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 7.4989420933245574)
# SUCCEESS: cost change < tolFun
# ('cost = ', 52.886164015972149, 'KL = ', 2.8726326448837338, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 5.6234132519034903)
# SUCCEESS: cost change < tolFun
# ('cost = ', 49.814792008668874, 'KL = ', 4.1608043280748852, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 4.8696752516586308)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 48.405917835212087, 'KL = ', 5.0094802277143096, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 4.8696752516586308)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 227.681461293
# mean value of real cost is 352.417396655
# mean value of real cost is 269.657309341
# mean value of real cost is 270.24146862
# mean value of real cost is 228.731952589
# mean value of real cost is 249.791018285
# mean value of real cost is 258.076743743
# mean value of real cost is 271.106690635
# mean value of real cost is 355.208837602
# mean value of real cost is 369.192162448
# mean value of real cost is 324.645783649
# mean value of real cost is 252.496374138
# mean value of real cost is 213.104287613
# mean value of real cost is 190.844264925
# mean value of real cost is 346.434224637
# mean value of real cost is 244.312034051
# mean value of real cost is 216.929739114
# mean value of real cost is 188.171091602
# mean value of real cost is 226.721283531
# mean value of real cost is 191.08412603
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 4.8696752516586308)
# SUCCEESS: cost change < tolFun
# ('cost = ', 43.991813657594207, 'KL = ', 5.211882641480388, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 4.8696752516586308)
# trajectory optimization is finished Traj estimated cost is 42.1041144379
# policy optimization start!!
# 1.59199
# 0.505883
# 0.515479
# 0.520963
# 0.516049
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 87.5077032529
# test starts
# mean value of real cost is 56.2160092622
# mean value of real cost is 92.6157049593
# mean value of real cost is 59.19186131
# iteration =  2
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 259.846798567
# mean value of real cost is 210.056131058
# mean value of real cost is 182.957184089
# mean value of real cost is 174.531850356
# mean value of real cost is 213.337272134
# mean value of real cost is 224.592464482
# mean value of real cost is 238.987245951
# mean value of real cost is 198.388087431
# mean value of real cost is 225.861200189
# mean value of real cost is 176.802193168
# mean value of real cost is 162.484886097
# mean value of real cost is 183.862562873
# mean value of real cost is 211.481463777
# mean value of real cost is 165.106305409
# mean value of real cost is 238.04720394
# mean value of real cost is 190.755969476
# mean value of real cost is 195.296993382
# mean value of real cost is 179.396117404
# mean value of real cost is 225.500526959
# mean value of real cost is 207.48878585
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 30.785379886340476, 'KL = ', 26.824229108401951, 'epsilon = ', 5)
# ('KL > epsilon // eta = ', 10.0)
# SUCCEESS: cost change < tolFun
# ('cost = ', 40.40983592457291, 'KL = ', 0.73462354875050395, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 35.95164706090403, 'KL = ', 5.0731576518105861, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.1622776601683795)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 209.485150052
# mean value of real cost is 193.890744173
# mean value of real cost is 196.271518792
# mean value of real cost is 176.671329
# mean value of real cost is 203.206250562
# mean value of real cost is 221.780606028
# mean value of real cost is 359.749903102
# mean value of real cost is 179.604234672
# mean value of real cost is 190.565877847
# mean value of real cost is 186.572168543
# mean value of real cost is 163.486052551
# mean value of real cost is 203.32571271
# mean value of real cost is 175.568984144
# mean value of real cost is 191.163149368
# mean value of real cost is 174.668905496
# mean value of real cost is 190.320571303
# mean value of real cost is 199.068824123
# mean value of real cost is 175.218303156
# mean value of real cost is 224.338644278
# mean value of real cost is 199.609631241
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 3.1622776601683795)
# Cholesky failed at 6
# Cholesky failed at 6
# Cholesky failed at 6
# Cholesky failed at 6
# EXIT : lamda > lamdaMax
# ('cost = ', 43.848262787469082, 'KL = ', inf, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 31.622776601683796)
# Cholesky failed at 31
# Cholesky failed at 31
# Cholesky failed at 31
# EXIT : lamda > lamdaMax
# ('cost = ', 68.455911106443182, 'KL = ', inf, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 316.22776601683796)
# trajOpt.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   + np.log( np.linalg.det(var[i,:,:]) / np.linalg.det(self.Quu_inv_save[i,:,:])) )
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.311514353075836, 'KL = ', 0.0024386952677754935, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 100.00000000000001)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.292036029965772, 'KL = ', 0.0086269602457726101, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 56.234132519034915)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.255174042578489, 'KL = ', 0.022619085578719264, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 42.169650342858233)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.250395506396941, 'KL = ', 0.037765498940451697, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 36.517412725483773)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.244989660222927, 'KL = ', 0.049023394540690657, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 33.982083289425596)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.239256673381675, 'KL = ', 0.055902475969711159, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 32.781211513934586)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.233359441557809, 'KL = ', 0.059713193173589717, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 32.196784442513795)
# SUCCEESS: cost change < tolFun
# ('cost = ', 68.22738264057493, 'KL = ', 0.061726329902745097, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 31.908489806291087)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 179.126322663
# mean value of real cost is 167.205928533
# mean value of real cost is 179.974002606
# mean value of real cost is 185.204248645
# mean value of real cost is 218.152090203
# mean value of real cost is 195.906182881
# mean value of real cost is 169.972576695
# mean value of real cost is 188.345808304
# mean value of real cost is 194.196259701
# mean value of real cost is 169.457928831
# mean value of real cost is 192.720413615
# mean value of real cost is 209.706322067
# mean value of real cost is 195.63959249
# mean value of real cost is 197.923945632
# mean value of real cost is 250.04927175
# mean value of real cost is 189.812689254
# mean value of real cost is 244.994965906
# mean value of real cost is 164.662602119
# mean value of real cost is 188.18110525
# mean value of real cost is 179.004639098
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 31.908489806291087)
# SUCCEESS: cost change < tolFun
# ('cost = ', 52.68491118111244, 'KL = ', 0.13693060103015797, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1908489806291089)
# SUCCEESS: cost change < tolFun
# ('cost = ', 43.083458129638743, 'KL = ', 5.3780296392942271, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.1908489806291089)
# trajectory optimization is finished Traj estimated cost is 49.2558148701
# policy optimization start!!
# 1.28183
# 1.59334
# 1.56319
# 1.46808
# 1.57497
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 57.7508236819
# ('epsilon is', 11.257165598652938)
# test starts
# mean value of real cost is 62.3026199706
# mean value of real cost is 96.5073187154
# mean value of real cost is 78.9523116317
# iteration =  3
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 248.49140961
# mean value of real cost is 224.169602024
# mean value of real cost is 209.571309181
# mean value of real cost is 193.485674519
# mean value of real cost is 141.513106324
# mean value of real cost is 158.108462846
# mean value of real cost is 161.813986704
# mean value of real cost is 258.090305775
# mean value of real cost is 149.247314424
# mean value of real cost is 138.441860704
# mean value of real cost is 186.937676375
# mean value of real cost is 224.536660833
# mean value of real cost is 179.90430343
# mean value of real cost is 152.150324788
# mean value of real cost is 287.559856846
# mean value of real cost is 207.385423493
# mean value of real cost is 185.275839756
# mean value of real cost is 163.808732478
# mean value of real cost is 180.82311451
# mean value of real cost is 267.071102246
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 31.902910644003391, 'KL = ', 21.908257385705483, 'epsilon = ', 11.257165598652938)
# ('KL > epsilon // eta = ', 10.0)
# SUCCEESS: cost change < tolFun
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1915896b0402> in <module>()
#       1 myGPS = mdGPS('hi')
# ----> 2 W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/아카이브/gps_unicycle.py in update(self)
#     209                 # 4. trajectory optimization
#     210                 self.myTraj.setEnv(self.myPolicy,eta,self.epsilon,K_fit,k_fit,myFitModelSet[j])
# --> 211                 x_new,u_new, Quu_new, Quu_inv_new, eta_new, cost_new, K_new, k_new = self.myTraj.iterDGD(self.x0[j,:],uNominal)
#     212                 localPolicySet[j] = policyClass.policy("local",ix,iu,N)
#     213                 localPolicySet[j].setter(K_new,k_new,x_new,u_new,Quu_inv_new)
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/아카이브/trajOpt.pyc in iterDGD(self, x0, uIni)
#     649             x_temp, u_temp, Quu_temp, Quu_inv_temp, K_temp, k_temp, flag_lamda = self.update(x0,uIni)
#     650             cost = self.getCost(x_temp,u_temp)
# --> 651             kl = self.getKL(x_temp,u_temp,self.K_fit,self.k_fit)
#     652             print("cost = ", cost, "KL = ", kl, "epsilon = ", self.epsilon)
#     653
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/아카이브/trajOpt.pyc in getKL(self, x, u, K_fit, k_fit)
#     196                             + np.dot( np.dot( np.transpose(u_diff) ,var_inv[i,:,:]), u_diff) \
#     197                             - self.model.iu \
# --> 198                             + np.log( np.linalg.det(var[i,:,:]) / np.linalg.det(self.Quu_inv_save[i,:,:])) )
#     199         return np.sum( temp_KL )
#     200
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in det(a)
#    1817     _assertRankAtLeast2(a)
#    1818     _assertNdSquareness(a)
# -> 1819     t, result_t = _commonType(a)
#    1820     signature = 'D->D' if isComplexType(t) else 'd->d'
#    1821     r = _umath_linalg.det(a, signature=signature)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _commonType(*arrays)
#     145             if isComplexType(a.dtype.type):
#     146                 is_complex = True
# --> 147             rt = _realType(a.dtype.type, default=None)
#     148             if rt is None:
#     149                 # unsupported inexact scalar
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _realType(t, default)
#     123
#     124 def _realType(t, default=double):
# --> 125     return _real_types_map.get(t, default)
#     126
#     127 def _complexType(t, default=cdouble):
#
# KeyboardInterrupt:

# %%
# i=4
np.savetxt('w1.txt',W1_save[i,:,:])
np.savetxt('w2.txt',W2_save[i,:,:])
np.savetxt('w3.txt',W3_save[i,:,:])
np.savetxt('b1.txt',b1_save[i,:])
np.savetxt('b2.txt',b2_save[i,:])
np.savetxt('b3.txt',b3_save[i,:])
# np.savetxt('var.txt',var_save[i,:,:])

# %%
for im in range(2) :
    while True :
        try :
            input("input number ")
        except NameError :
            print(".. input number")
        except SyntaxError :
            print(".. input number")
        else :
            print("Let's go to the next step")
            break
    print im

# %%
y = np.ones((1,10))
x = np.ones((1,10))
print_np( np.arctan2(y,x) )
