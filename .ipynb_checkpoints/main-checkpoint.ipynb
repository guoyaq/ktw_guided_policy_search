# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
from mdgps import mdGPS
myGPS = mdGPS('hi')
W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
# Out:
# initial trajectories from iLQR
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           192.987     149         119         1.42        0.0
# 1           43.8982     4.42        6.26        0.23        -0.2
# ('sample generation cost = ', 132.15123169958426)
# ('sample generation cost = ', 134.75027078383783)
# ('sample generation cost = ', 128.47195388881286)
# ('sample generation cost = ', 142.54358792321543)
# ('sample generation cost = ', 142.09855371545248)
# ('sample generation cost = ', 172.97026147253862)
# ('sample generation cost = ', 134.80516265821183)
# ('sample generation cost = ', 118.30892537274453)
# ('sample generation cost = ', 156.34965176019102)
# ('sample generation cost = ', 137.87032237647358)
# ('sample generation cost = ', 147.75875540411766)
# ('sample generation cost = ', 135.74395685461937)
# ('sample generation cost = ', 145.44560668215479)
# ('sample generation cost = ', 139.68100743200432)
# ('sample generation cost = ', 151.96313386508862)
# ('sample generation cost = ', 146.91709232511573)
# ('sample generation cost = ', 147.38516455427228)
# ('sample generation cost = ', 137.80704579903147)
# ('sample generation cost = ', 134.92505184598664)
# ('sample generation cost = ', 142.34911471052425)
# initial policy optimization starts!!
# epoch 1, Training Loss= 2.382659
# epoch 11, Training Loss= 2.080575
# epoch 21, Training Loss= 2.010228
# epoch 31, Training Loss= 2.040750
# epoch 41, Training Loss= 2.009607
# Optimization - policy mean is done
# Optimization - policy variance is done
# ======================== Mirror descent GPS ============================
# iteration =  1
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 183.950372146
# mean value of real cost is 153.201841994
# mean value of real cost is 137.773108241
# mean value of real cost is 128.711257832
# mean value of real cost is 166.781107941
# mean value of real cost is 159.6971427
# mean value of real cost is 165.832473431
# mean value of real cost is 136.309409387
# mean value of real cost is 153.12325598
# mean value of real cost is 124.530237951
# mean value of real cost is 162.277034803
# mean value of real cost is 168.93811065
# mean value of real cost is 138.828004336
# mean value of real cost is 150.240522546
# mean value of real cost is 205.746040182
# mean value of real cost is 158.775347943
# mean value of real cost is 163.382902478
# mean value of real cost is 143.752517038
# mean value of real cost is 137.470906998
# mean value of real cost is 151.673873467
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.536689453396768, 'KL = ', 19.767749337473091, 'epsilon = ', 5)
# ('KL > epsilon // increased eta = ', 10.0)
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.792362930072763, 'KL = ', 0.5177818787263746, 'epsilon = ', 5)
# ('KL < epsilon // decreased eta = ', 3.1622776601683795)
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.618711864766894, 'KL = ', 3.6833825122025714, 'epsilon = ', 5)
# ('KL < epsilon // decreased eta = ', 1.7782794100389228)
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.570444504123884, 'KL = ', 8.9688874002940455, 'epsilon = ', 5)
# ('KL > epsilon // increased eta = ', 2.3713737056616555)
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.592635264776639, 'KL = ', 5.8105952921080313, 'epsilon = ', 5)
# ('KL > epsilon // increased eta = ', 2.7384196342643614)
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.605131820918153, 'KL = ', 4.637642724210143, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('max(c) = ', 0.43645148753004914)
# update lagrangian variables
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.611930568757657, 'KL = ', 4.6373556645213139, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('max(c) = ', 0.4295410295536275)
# update lagrangian variables
# SUCCEESS: cost change < tolFun
# ('cost = ', 38.635280673471811, 'KL = ', 4.6520556751252338, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('max(c) = ', 0.40673424619277032)
# update lagrangian variables
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 38.716302238880054, 'KL = ', 4.7233783260342292, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('max(c) = ', 0.33780172020699784)
# update lagrangian variables
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 38.861129422969846, 'KL = ', 4.9085288418001261, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('max(c) = ', 0.22073956212532764)
# update lagrangian variables
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 38.993991701319381, 'KL = ', 5.1106851934661428, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('max(c) = ', 0.11445249876759611)
# update lagrangian variables
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 39.044546523743527, 'KL = ', 5.2564566085118019, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# ('EXIT : max(c)', 0.062358748284680132, ' < tolConst, tolConst becomes, ', 0.09000000000000001)
# trajectory optimization is finished Traj estimated cost is 39.0445456694
# policy optimization start!!
# epoch 1, Training Loss= 0.537215
# epoch 11, Training Loss= 0.336267
# epoch 21, Training Loss= 0.248083
# epoch 31, Training Loss= 0.171694
# epoch 41, Training Loss= 0.174795
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 40.0635821606
# mean value of real cost is 39.9325340166
# iteration =  2
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 119.160226298
# mean value of real cost is 119.763955706
# mean value of real cost is 104.2590002
# mean value of real cost is 106.19245407
# mean value of real cost is 110.071417583
# mean value of real cost is 107.971398617
# mean value of real cost is 119.33937983
# mean value of real cost is 109.91431418
# mean value of real cost is 109.613295648
# mean value of real cost is 123.362023861
# mean value of real cost is 115.759250977
# mean value of real cost is 107.82643619
# mean value of real cost is 114.047083832
# mean value of real cost is 121.78870983
# mean value of real cost is 151.369237818
# mean value of real cost is 116.181463245
# mean value of real cost is 129.572117166
# mean value of real cost is 118.769918077
# mean value of real cost is 114.156693275
# mean value of real cost is 117.305006539
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-321ee83de8b8> in <module>()
#       1 from mdgps import mdGPS
#       2 myGPS = mdGPS('hi')
# ----> 3 W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/mdgps.py in update(self)
#     194                 else :
#     195                     xNominal, uNominal = localPolicySet[j].x_nominal,localPolicySet[j].u_nominal
# --> 196                     x_fit, u_fit_m, cost_fit, o_fit = self.driveRobot(self.x0[j,:],self.onPolicy,i,localPolicySet[j],False)
#     197                 cost_real_ini[j] = np.mean(cost_fit)
#     198
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/mdgps.py in driveRobot(self, x0, onPolicy, mainIter, localPolicy, flag_test, x_new, u_new)
#     416             return None
#     417         else :
# --> 418             getPlot(x_fit,u_fit_m,self.x_t,num_fit,N)
#     419             return x_fit, u_fit_m, cost_fit, o_fit
#     420
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/gps_util.pyc in getPlot(x_fit, u_fit_m, x_t, num_fit, N, x_new, u_new)
#     144     plt.xlabel('time (s)', fontsize = fS)
#     145     plt.ylabel('w (rad/s)', fontsize = fS)
# --> 146     plt.show()
#     147     plt.figure(2,figsize=(20, 7))
#     148     for im in range(num_fit) :
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     153     """
#     154     global _show
# --> 155     return _show(*args, **kw)
#     156
#     157
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     156             publish_display_data(data=obj, metadata=metadata)
#     157         else:
# --> 158             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     159             if not format_dict:
#     160                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     175             md = None
#     176             try:
# --> 177                 data = formatter(obj)
#     178             except:
#     179                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     220     """show traceback on failed format call"""
#     221     try:
# --> 222         r = method(self, *args, **kwargs)
#     223     except NotImplementedError:
#     224         # don't warn on NotImplementedErrors
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     226
#     227     if 'png' in formats:
# --> 228         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     229     if 'retina' in formats or 'png2x' in formats:
#     230         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2156                     orientation=orientation,
#    2157                     dryrun=True,
# -> 2158                     **kwargs)
#    2159                 renderer = self.figure._cachedRenderer
#    2160                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     531             _png.write_png(renderer._renderer.buffer_rgba(),
#     532                            renderer.width, renderer.height,
# --> 533                            filename_or_obj, self.figure.dpi)
#     534         finally:
#     535             if close:
#
# KeyboardInterrupt:

# %%
# i=4
np.savetxt('w1.txt',W1_save[i,:,:])
np.savetxt('w2.txt',W2_save[i,:,:])
np.savetxt('w3.txt',W3_save[i,:,:])
np.savetxt('b1.txt',b1_save[i,:])
np.savetxt('b2.txt',b2_save[i,:])
np.savetxt('b3.txt',b3_save[i,:])
# np.savetxt('var.txt',var_save[i,:,:])

# %%
def abc(a=10) :
    print a
abc()
