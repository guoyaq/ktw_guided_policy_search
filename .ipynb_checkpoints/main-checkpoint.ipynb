# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
# import model
# import cost
# import iLQR
# import poliOpt
# import trajOpt
# import policyClass
# import modelLearn
# from gps_util import getCostNN, getCostAppNN, getCostTraj, getObs, getDesired
from mdgps import mdGPS

# %%
myGPS = mdGPS('hi')
W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
# Out:
# initial trajectories from iLQR
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           471.875     213         213         1.6         0.0
# ('sample generation cost = ', 459.24875165103003)
# ('sample generation cost = ', 420.5000307505473)
# ('sample generation cost = ', 388.79374337543885)
# ('sample generation cost = ', 325.34458858548703)
# ('sample generation cost = ', 319.13396304599416)
# ('sample generation cost = ', 546.35364611755222)
# ('sample generation cost = ', 588.68465928207024)
# ('sample generation cost = ', 433.49904539287809)
# ('sample generation cost = ', 446.9266916400818)
# ('sample generation cost = ', 395.30530911359392)
# ('sample generation cost = ', 704.87370311429822)
# ('sample generation cost = ', 589.87308574734652)
# ('sample generation cost = ', 408.23444124217485)
# ('sample generation cost = ', 499.8505980036789)
# ('sample generation cost = ', 474.55795240715508)
# ('sample generation cost = ', 466.70654311579597)
# ('sample generation cost = ', 519.53119200900085)
# ('sample generation cost = ', 283.44443213813986)
# ('sample generation cost = ', 457.65462937289783)
# ('sample generation cost = ', 407.31389250503099)
# initial policy optimization starts!!
# epoch 1, Training Loss= 2.046673
# epoch 11, Training Loss= 2.073306
# epoch 21, Training Loss= 2.010926
# epoch 31, Training Loss= 2.030345
# epoch 41, Training Loss= 2.008929
# epoch 51, Training Loss= 1.994648
# epoch 61, Training Loss= 1.998057
# epoch 71, Training Loss= 2.061164
# epoch 81, Training Loss= 1.991767
# epoch 91, Training Loss= 2.000882
# Optimization - policy mean is done
# Optimization - policy variance is done
# initial policy parameter is updated true cost is  10000.0
# ======================== Mirror descent GPS ============================
# iteration =  1
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 343.590669541
# mean value of real cost is 395.649333241
# mean value of real cost is 450.711716935
# mean value of real cost is 395.157980888
# mean value of real cost is 415.839323848
# mean value of real cost is 412.45408766
# mean value of real cost is 637.278006568
# mean value of real cost is 387.229220824
# mean value of real cost is 463.31721756
# mean value of real cost is 579.739038559
# mean value of real cost is 456.201969878
# mean value of real cost is 691.582996834
# mean value of real cost is 346.03016236
# mean value of real cost is 533.144159934
# mean value of real cost is 434.015651167
# mean value of real cost is 455.724000674
# mean value of real cost is 325.553524958
# mean value of real cost is 534.034949132
# mean value of real cost is 500.9005861
# mean value of real cost is 581.410210577
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 139.33307680479484, 'KL = ', 59.688491292721096, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 222.41915356731138, 'KL = ', 3.4899211313086873, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 172.37032972730157, 'KL = ', 17.577470188070897, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 5.6234132519034912)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 197.37014291265413, 'KL = ', 8.2068390309584451, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 7.4989420933245592)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 210.19197592510329, 'KL = ', 5.4071560941737635, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 7.4989420933245592)
# trajectory optimization is finished Traj estimated cost is 210.191969757
# policy optimization start!!
# epoch 1, Training Loss= 0.719044
# epoch 11, Training Loss= 0.306663
# epoch 21, Training Loss= 0.286473
# epoch 31, Training Loss= 0.267389
# epoch 41, Training Loss= 0.254508
# epoch 51, Training Loss= 0.249354
# epoch 61, Training Loss= 0.239002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1915896b0402> in <module>()
#       1 myGPS = mdGPS('hi')
# ----> 2 W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/mdgps.py in update(self)
#     266             self.myPolicy.setEnv(self.maxIterNN,stepIni)
#     267             for jj in range(20) :
# --> 268                 W1,b1,W2,b2,W3,b3,pol_var,pol_var_inv = self.myPolicy.update(o_save,u_save,var_inv_save * np.mean(eta_save) ,var_inv_set_save,self.num_ini*self.num_sample)
#     269                 c_temp = np.zeros(self.num_ini)
#     270                 for j in range(self.num_ini) :
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/poliOpt.pyc in update(self, x, u, Q, Q_set, set_num)
#     177
#     178         # mean optimization - backpropagation
# --> 179         self.meanOpt(set_num)
#     180
#     181         # variance optimization
#
# /Users/keemtw/Documents/Study/Machine Learning/Code/my_GuidedPolicySearch/poliOpt.pyc in meanOpt(self, set_num)
#     123                 y_batch = self.input_label[index,:]
#     124                 W_batch = self.var_inv_label[index,:,:]
# --> 125                 self.sess.run(self.optimizer, feed_dict={self.input_x: x_batch, self.input_y: y_batch, self.Weight : W_batch})
#     126                 loss[j] = self.sess.run(self.loss,feed_dict={self.input_x: x_batch, self.input_y: y_batch, self.Weight : W_batch})
#     127             if i % 10 == 0 :
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/keemtw/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# i=4
np.savetxt('w1.txt',W1_save[i,:,:])
np.savetxt('w2.txt',W2_save[i,:,:])
np.savetxt('w3.txt',W3_save[i,:,:])
np.savetxt('b1.txt',b1_save[i,:])
np.savetxt('b2.txt',b2_save[i,:])
np.savetxt('b3.txt',b3_save[i,:])
# np.savetxt('var.txt',var_save[i,:,:])
