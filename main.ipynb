# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
# import model
# import cost
# import iLQR
# import poliOpt
# import trajOpt
# import policyClass
# import modelLearn
# from gps_util import getCostNN, getCostAppNN, getCostTraj, getObs, getDesired
from gps_unicycle import mdGPS

# %%
myGPS = mdGPS('hi')
W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
# Out:
# initial trajectories from iLQR
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           120.8       95.1        95.1        1.07        0.0
# 1           25.6977     2.36e-09    2.32e-09    4.24e-06    -0.2
# SUCCEESS: cost change < tolFun
# ('sample generation cost = ', 229.40289225375045)
# ('sample generation cost = ', 182.65570549055718)
# ('sample generation cost = ', 189.56612276461959)
# ('sample generation cost = ', 186.50947602057224)
# ('sample generation cost = ', 160.4078536574329)
# ('sample generation cost = ', 198.2526182733437)
# ('sample generation cost = ', 193.45253519041677)
# ('sample generation cost = ', 181.33807588800914)
# ('sample generation cost = ', 173.1914369917537)
# ('sample generation cost = ', 203.06377149700472)
# ('sample generation cost = ', 168.70694944967346)
# ('sample generation cost = ', 199.27889039571767)
# ('sample generation cost = ', 178.79684710182767)
# ('sample generation cost = ', 180.46904118888068)
# ('sample generation cost = ', 195.45497944467718)
# ('sample generation cost = ', 181.91057065249808)
# ('sample generation cost = ', 204.24532877923966)
# ('sample generation cost = ', 195.82612241700201)
# ('sample generation cost = ', 161.61661619477115)
# ('sample generation cost = ', 170.47877011034268)
# initial policy optimization starts!!
# epoch 1, Training Loss= 2.032191
# epoch 11, Training Loss= 1.947336
# epoch 21, Training Loss= 2.007601
# epoch 31, Training Loss= 2.001309
# epoch 41, Training Loss= 2.083640
# epoch 51, Training Loss= 2.044715
# epoch 61, Training Loss= 1.971010
# epoch 71, Training Loss= 2.082818
# epoch 81, Training Loss= 2.034179
# epoch 91, Training Loss= 2.040775
# Optimization - policy mean is done
# Optimization - policy variance is done
# initial policy parameter is updated true cost is  10000.0
# ======================== Mirror descent GPS ============================
# iteration =  1
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 172.058693092
# mean value of real cost is 159.284105664
# mean value of real cost is 189.67738461
# mean value of real cost is 186.711821676
# mean value of real cost is 172.920621973
# mean value of real cost is 177.143887927
# mean value of real cost is 192.242084655
# mean value of real cost is 180.689737551
# mean value of real cost is 166.525633902
# mean value of real cost is 202.714755643
# mean value of real cost is 188.579308466
# mean value of real cost is 159.015535856
# mean value of real cost is 188.625758412
# mean value of real cost is 184.909704578
# mean value of real cost is 187.571071625
# mean value of real cost is 196.84831933
# mean value of real cost is 199.243690087
# mean value of real cost is 186.706993696
# mean value of real cost is 183.678788546
# mean value of real cost is 188.230872915
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.401201990115172, 'KL = ', 30.436935161708078, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS: cost change < tolFun
# ('cost = ', 30.852773592554186, 'KL = ', 0.75299675039566605, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 28.995068849695365, 'KL = ', 5.659865986267004, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 5.6234132519034912)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 29.969255889017514, 'KL = ', 2.1285624477890668, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 4.2169650342858223)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 29.483689384843686, 'KL = ', 3.502347419826886, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.6517412725483771)
# SUCCEESS: cost change < tolFun
# ('cost = ', 29.238286931616454, 'KL = ', 4.4630156885953021, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.3982083289425598)
# SUCCEESS: cost change < tolFun
# ('cost = ', 29.116133686777907, 'KL = ', 5.0291480241378004, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.3982083289425598)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 193.342084794
# mean value of real cost is 218.976098122
# mean value of real cost is 194.681187004
# mean value of real cost is 175.799281223
# mean value of real cost is 198.79722055
# mean value of real cost is 184.25287796
# mean value of real cost is 192.761813331
# mean value of real cost is 177.622222448
# mean value of real cost is 180.672832999
# mean value of real cost is 195.91964482
# mean value of real cost is 198.483169951
# mean value of real cost is 201.509251724
# mean value of real cost is 182.64900666
# mean value of real cost is 204.274400198
# mean value of real cost is 187.503111928
# mean value of real cost is 176.319040748
# mean value of real cost is 181.611542157
# mean value of real cost is 199.245679942
# mean value of real cost is 167.320417416
# mean value of real cost is 203.200832921
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 3.3982083289425598)
# SUCCEESS: cost change < tolFun
# ('cost = ', 35.513305993610487, 'KL = ', 5.0306790169853128, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.3982083289425598)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 180.991147367
# mean value of real cost is 182.49009248
# mean value of real cost is 172.83752576
# mean value of real cost is 188.075012981
# mean value of real cost is 206.170487877
# mean value of real cost is 176.399057439
# mean value of real cost is 187.798261087
# mean value of real cost is 170.730206912
# mean value of real cost is 180.539882879
# mean value of real cost is 189.224724974
# mean value of real cost is 212.964309208
# mean value of real cost is 201.323813346
# mean value of real cost is 192.465077426
# mean value of real cost is 187.362448957
# mean value of real cost is 224.205819476
# mean value of real cost is 183.041372929
# mean value of real cost is 174.456560928
# mean value of real cost is 184.457188032
# mean value of real cost is 190.968101955
# mean value of real cost is 211.966901774
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 3.3982083289425598)
# SUCCEESS: cost change < tolFun
# ('cost = ', 35.518952323380702, 'KL = ', 5.0435579716077452, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.3982083289425598)
# trajectory optimization is finished Traj estimated cost is 33.3365939599
# policy optimization start!!
# epoch 1, Training Loss= 0.013662
# epoch 11, Training Loss= 0.006159
# epoch 21, Training Loss= 0.005968
# epoch 31, Training Loss= 0.005979
# epoch 41, Training Loss= 0.005892
# epoch 51, Training Loss= 0.005917
# epoch 61, Training Loss= 0.005828
# epoch 71, Training Loss= 0.005699
# epoch 81, Training Loss= 0.005667
# epoch 91, Training Loss= 0.005831
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 37.1620166695
# test starts
# mean value of real cost is 28.3730510152
# mean value of real cost is 35.2224943608
# mean value of real cost is 34.872856642
# iteration =  2
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 132.577769792
# mean value of real cost is 130.429253853
# mean value of real cost is 133.054302253
# mean value of real cost is 145.980842254
# mean value of real cost is 134.091047273
# mean value of real cost is 133.022065279
# mean value of real cost is 139.679117086
# mean value of real cost is 145.576551889
# mean value of real cost is 150.93055127
# mean value of real cost is 140.71966765
# mean value of real cost is 146.821979913
# mean value of real cost is 143.584863201
# mean value of real cost is 137.558756685
# mean value of real cost is 138.632930411
# mean value of real cost is 142.414143386
# mean value of real cost is 130.327214823
# mean value of real cost is 148.601331808
# mean value of real cost is 133.89332191
# mean value of real cost is 147.005001787
# mean value of real cost is 150.496721958
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.919447959547679, 'KL = ', 21.172586657266834, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 28.454282157164414, 'KL = ', 0.43542857567801152, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.720232437095397, 'KL = ', 3.5234477021135042, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 1.7782794100389228)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.28920948902579, 'KL = ', 9.0744756180920252, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 2.3713737056616555)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.502336928812177, 'KL = ', 5.716078747074663, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 2.7384196342643614)
# SUCCEESS: cost change < tolFun
# ('cost = ', 27.611440092186697, 'KL = ', 4.4991160840109767, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 2.5482967479793466)
# SUCCEESS: cost change < tolFun
# ('cost = ', 27.556835975793842, 'KL = ', 5.0744481014093576, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.5482967479793466)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 140.594264585
# mean value of real cost is 148.703044848
# mean value of real cost is 182.119790942
# mean value of real cost is 156.332323284
# mean value of real cost is 147.104915134
# mean value of real cost is 151.681442046
# mean value of real cost is 154.16287876
# mean value of real cost is 146.057064164
# mean value of real cost is 148.957268911
# mean value of real cost is 177.30149005
# mean value of real cost is 145.101379467
# mean value of real cost is 139.492820279
# mean value of real cost is 134.993779995
# mean value of real cost is 143.455023259
# mean value of real cost is 162.314536789
# mean value of real cost is 147.21355872
# mean value of real cost is 148.18984263
# mean value of real cost is 153.299050749
# mean value of real cost is 139.218348128
# mean value of real cost is 161.901053596
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 2.5482967479793466)
# SUCCEESS: cost change < tolFun
# ('cost = ', 34.123435943431019, 'KL = ', 5.0949911506586307, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.5482967479793466)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 140.981753034
# mean value of real cost is 160.642750568
# mean value of real cost is 156.954204968
# mean value of real cost is 172.501730599
# mean value of real cost is 141.790015226
# mean value of real cost is 132.085035929
# mean value of real cost is 127.969422005
# mean value of real cost is 145.057693321
# mean value of real cost is 146.028646732
# mean value of real cost is 163.827329701
# mean value of real cost is 161.178162612
# mean value of real cost is 133.291215963
# mean value of real cost is 169.02926629
# mean value of real cost is 149.642194323
# mean value of real cost is 164.64151666
# mean value of real cost is 138.311558338
# mean value of real cost is 133.742335519
# mean value of real cost is 150.144564494
# mean value of real cost is 139.419010384
# mean value of real cost is 140.515325375
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 2.5482967479793466)
# SUCCEESS: cost change < tolFun
# ('cost = ', 34.073738035420426, 'KL = ', 5.097943399967944, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.5482967479793466)
# trajectory optimization is finished Traj estimated cost is 31.9002440102
# policy optimization start!!
# epoch 1, Training Loss= 0.005703
# epoch 11, Training Loss= 0.004059
# epoch 21, Training Loss= 0.004222
# epoch 31, Training Loss= 0.004088
# epoch 41, Training Loss= 0.004160
# epoch 51, Training Loss= 0.004192
# epoch 61, Training Loss= 0.003964
# epoch 71, Training Loss= 0.004085
# epoch 81, Training Loss= 0.004002
# epoch 91, Training Loss= 0.003919
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 33.497948606
# ('epsilon is', 8.2333315452780536)
# test starts
# mean value of real cost is 26.937294806
# mean value of real cost is 33.4308965874
# mean value of real cost is 33.4908647218
# iteration =  3
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 132.757686143
# mean value of real cost is 106.685028824
# mean value of real cost is 117.446789416
# mean value of real cost is 113.036210138
# mean value of real cost is 112.219005863
# mean value of real cost is 104.049301166
# mean value of real cost is 122.45097156
# mean value of real cost is 109.547142461
# mean value of real cost is 117.925253594
# mean value of real cost is 125.503063339
# mean value of real cost is 118.964285207
# mean value of real cost is 115.845197061
# mean value of real cost is 116.346779837
# mean value of real cost is 125.528488612
# mean value of real cost is 120.906875555
# mean value of real cost is 128.384604232
# mean value of real cost is 113.572243776
# mean value of real cost is 119.585065566
# mean value of real cost is 120.703348852
# mean value of real cost is 116.115114192
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.562037832175513, 'KL = ', 14.329940345672883, 'epsilon = ', 8.2333315452780536)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.276982561425644, 'KL = ', 0.25390204987556297, 'epsilon = ', 8.2333315452780536)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.985703321251755, 'KL = ', 2.1640006355353711, 'epsilon = ', 8.2333315452780536)
# ('KL < epsilon // eta = ', 1.7782794100389228)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.776371731227442, 'KL = ', 5.8185372403196158, 'epsilon = ', 8.2333315452780536)
# ('KL < epsilon // eta = ', 1.333521432163324)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.667020912022799, 'KL = ', 9.2469989894690343, 'epsilon = ', 8.2333315452780536)
# ('PD is not satisfied // eta = ', 1.5399265260594919)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.72153405280832, 'KL = ', 7.3568802992108875, 'epsilon = ', 8.2333315452780536)
# ('KL < epsilon // eta = ', 1.4330125702369627)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.69419158513616, 'KL = ', 8.2541944396152882, 'epsilon = ', 8.2333315452780536)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1.4330125702369627)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 124.535131308
# mean value of real cost is 121.517628184
# mean value of real cost is 116.058129422
# mean value of real cost is 126.26177314
# mean value of real cost is 122.522080556
# mean value of real cost is 122.841291982
# mean value of real cost is 134.250880123
# mean value of real cost is 117.430583137
# mean value of real cost is 127.967614966
# mean value of real cost is 116.242200935
# mean value of real cost is 118.953119445
# mean value of real cost is 135.159752419
# mean value of real cost is 118.448501308
# mean value of real cost is 125.218748235
# mean value of real cost is 114.340142447
# mean value of real cost is 129.815576769
# mean value of real cost is 124.076692126
# mean value of real cost is 115.415561175
# mean value of real cost is 124.596568354
# mean value of real cost is 120.168926035
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1.4330125702369627)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 33.076796855137708, 'KL = ', 8.2627204297659844, 'epsilon = ', 8.2333315452780536)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1.4330125702369627)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 124.375064349
# mean value of real cost is 113.927365053
# mean value of real cost is 119.355402341
# mean value of real cost is 125.101328999
# mean value of real cost is 122.193242079
# mean value of real cost is 137.947879519
# mean value of real cost is 119.877253471
# mean value of real cost is 122.804950503
# mean value of real cost is 123.932701441
# mean value of real cost is 127.990750415
# mean value of real cost is 124.03205286
# mean value of real cost is 124.923828918
# mean value of real cost is 110.526373378
# mean value of real cost is 139.923888411
# mean value of real cost is 123.711557681
# mean value of real cost is 111.883036706
# mean value of real cost is 113.913374324
# mean value of real cost is 128.524631754
# mean value of real cost is 114.678815052
# mean value of real cost is 121.343455837
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1.4330125702369627)
# SUCCEESS: cost change < tolFun
# ('cost = ', 33.090669310230105, 'KL = ', 8.2731912438365232, 'epsilon = ', 8.2333315452780536)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1.4330125702369627)
# trajectory optimization is finished Traj estimated cost is 30.9444236046
# policy optimization start!!
# epoch 1, Training Loss= 0.002291
# epoch 11, Training Loss= 0.001903
# epoch 21, Training Loss= 0.001883
# epoch 31, Training Loss= 0.001876
# epoch 41, Training Loss= 0.001864
# epoch 51, Training Loss= 0.001867
# epoch 61, Training Loss= 0.001838
# epoch 71, Training Loss= 0.001856
# epoch 81, Training Loss= 0.001836
# epoch 91, Training Loss= 0.001851
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 31.7650683661
# ('epsilon is', 12.809451137487306)
# test starts
# mean value of real cost is 26.2411881834
# mean value of real cost is 32.680557331
# mean value of real cost is 32.6836846631
# iteration =  4
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 88.1304848031
# mean value of real cost is 92.4363345445
# mean value of real cost is 94.4244099518
# mean value of real cost is 89.5548509419
# mean value of real cost is 85.6405184021
# mean value of real cost is 100.256157777
# mean value of real cost is 87.2526931779
# mean value of real cost is 81.5887631429
# mean value of real cost is 96.3002048316
# mean value of real cost is 87.7300798561
# mean value of real cost is 83.0774499102
# mean value of real cost is 94.4937692258
# mean value of real cost is 88.2972524612
# mean value of real cost is 89.9722972799
# mean value of real cost is 83.9325012314
# mean value of real cost is 98.8174624499
# mean value of real cost is 84.0260596058
# mean value of real cost is 92.9231557827
# mean value of real cost is 83.5307078472
# mean value of real cost is 83.4066666444
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.224266747726531, 'KL = ', 8.3294906668583, 'epsilon = ', 12.809451137487306)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.98158341930089, 'KL = ', 126.61793687951219, 'epsilon = ', 12.809451137487306)
# ('PD is not satisfied // eta = ', 0.31622776601683794)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.051910414514339, 'KL = ', 41.478230300508102, 'epsilon = ', 12.809451137487306)
# ('PD is not satisfied // eta = ', 0.56234132519034907)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.127460112701545, 'KL = ', 19.72408021818768, 'epsilon = ', 12.809451137487306)
# ('PD is not satisfied // eta = ', 0.74989420933245587)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.17425912136968, 'KL = ', 12.995394164868067, 'epsilon = ', 12.809451137487306)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.74989420933245587)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 100.548202801
# mean value of real cost is 102.006589233
# mean value of real cost is 93.8114329046
# mean value of real cost is 92.4256713713
# mean value of real cost is 95.985996195
# mean value of real cost is 112.534781766
# mean value of real cost is 99.645800272
# mean value of real cost is 100.279118335
# mean value of real cost is 104.946849898
# mean value of real cost is 102.312253595
# mean value of real cost is 99.5516183204
# mean value of real cost is 92.6371052462
# mean value of real cost is 107.170825113
# mean value of real cost is 90.6307118335
# mean value of real cost is 91.914261645
# mean value of real cost is 101.168340647
# mean value of real cost is 101.497029773
# mean value of real cost is 89.0119136652
# mean value of real cost is 106.243232422
# mean value of real cost is 91.8018195255
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.74989420933245587)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.613292565156144, 'KL = ', 13.026711082122571, 'epsilon = ', 12.809451137487306)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.74989420933245587)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 83.5822619731
# mean value of real cost is 98.5338635226
# mean value of real cost is 93.4639686623
# mean value of real cost is 88.953975596
# mean value of real cost is 97.8027988184
# mean value of real cost is 94.3978025815
# mean value of real cost is 102.982263489
# mean value of real cost is 87.5525375751
# mean value of real cost is 99.5268218192
# mean value of real cost is 101.019986219
# mean value of real cost is 97.0487322503
# mean value of real cost is 89.6190375214
# mean value of real cost is 99.7909989465
# mean value of real cost is 95.411672916
# mean value of real cost is 92.0769016629
# mean value of real cost is 95.7321481158
# mean value of real cost is 87.2909132132
# mean value of real cost is 105.96828113
# mean value of real cost is 102.154273237
# mean value of real cost is 102.328326865
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.74989420933245587)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.632983611910063, 'KL = ', 13.015179474689631, 'epsilon = ', 12.809451137487306)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.74989420933245587)
# trajectory optimization is finished Traj estimated cost is 30.4910698544
# policy optimization start!!
# epoch 1, Training Loss= 0.001246
# epoch 11, Training Loss= 0.001099
# epoch 21, Training Loss= 0.001066
# epoch 31, Training Loss= 0.001069
# epoch 41, Training Loss= 0.001037
# epoch 51, Training Loss= 0.001057
# epoch 61, Training Loss= 0.001057
# epoch 71, Training Loss= 0.001019
# epoch 81, Training Loss= 0.001037
# epoch 91, Training Loss= 0.001003
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 30.8800034563
# ('epsilon is', 20.979444309926375)
# test starts
# mean value of real cost is 25.9388686573
# mean value of real cost is 32.3323876883
# mean value of real cost is 32.3326909557
# iteration =  5
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# mean value of real cost is 70.7356696605
# mean value of real cost is 61.0784174412
# mean value of real cost is 75.7187390086
# mean value of real cost is 76.131193149
# mean value of real cost is 70.0335127358
# mean value of real cost is 66.5170171304
# mean value of real cost is 61.1387599251
# mean value of real cost is 70.7716083459
# mean value of real cost is 62.9690659488
# mean value of real cost is 68.1840169686
# mean value of real cost is 62.4570414952
# mean value of real cost is 65.8255281076
# mean value of real cost is 65.3393624465
# mean value of real cost is 65.4288008834
# mean value of real cost is 66.4876738997
# mean value of real cost is 69.0914051649
# mean value of real cost is 67.2609004446
# mean value of real cost is 65.0974023757
# mean value of real cost is 71.3653843676
# mean value of real cost is 73.0454032907
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.035591822217476, 'KL = ', 3.9760284343024397, 'epsilon = ', 20.979444309926375)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.903483699393433, 'KL = ', 86.844572640461905, 'epsilon = ', 20.979444309926375)
# ('PD is not satisfied // eta = ', 0.31622776601683794)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.953232765773091, 'KL = ', 23.542925895780872, 'epsilon = ', 20.979444309926375)
# ('PD is not satisfied // eta = ', 0.56234132519034907)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.99368174615341, 'KL = ', 10.188313622417192, 'epsilon = ', 20.979444309926375)
# ('KL < epsilon // eta = ', 0.42169650342858228)
# SUCCEESS: cost change < tolFun
# ('cost = ', 25.972703078552087, 'KL = ', 15.711527376854098, 'epsilon = ', 20.979444309926375)
# ('KL < epsilon // eta = ', 0.36517412725483772)
# SUCCEESS: cost change < tolFun
# ('cost = ', 25.962713965405765, 'KL = ', 19.304683296381988, 'epsilon = ', 20.979444309926375)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# (1, 'initial position in trajectory optimization')
# mean value of real cost is 72.347831483
# mean value of real cost is 73.4010984308
# mean value of real cost is 79.3031851192
# mean value of real cost is 85.4322222818
# mean value of real cost is 78.8794658972
# mean value of real cost is 75.4173826696
# mean value of real cost is 65.9779175516
# mean value of real cost is 75.8580010946
# mean value of real cost is 77.4823322421
# mean value of real cost is 72.5487068604
# mean value of real cost is 70.6449407047
# mean value of real cost is 62.4233995952
# mean value of real cost is 67.9681042151
# mean value of real cost is 81.0301051445
# mean value of real cost is 75.2480087268
# mean value of real cost is 79.5440893837
# mean value of real cost is 68.4025786824
# mean value of real cost is 78.1255790852
# mean value of real cost is 78.9762355534
# mean value of real cost is 75.6951264416
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.36517412725483772)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.432351340825605, 'KL = ', 19.330254984191566, 'epsilon = ', 20.979444309926375)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# (2, 'initial position in trajectory optimization')
# mean value of real cost is 69.4130387001
# mean value of real cost is 72.2224097742
# mean value of real cost is 73.4811981112
# mean value of real cost is 61.9250429566
# mean value of real cost is 79.2682748797
# mean value of real cost is 67.6817930072
# mean value of real cost is 71.7214681673
# mean value of real cost is 77.6643992213
# mean value of real cost is 62.5738385334
# mean value of real cost is 72.0605039368
# mean value of real cost is 75.2386057046
# mean value of real cost is 71.3844539351
# mean value of real cost is 77.0780462414
# mean value of real cost is 76.0791427406
# mean value of real cost is 80.0591682236
# mean value of real cost is 70.4677836614
# mean value of real cost is 77.0064645325
# mean value of real cost is 69.9262707684
# mean value of real cost is 70.8889378377
# mean value of real cost is 66.8715581071
# fit model prior !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.36517412725483772)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.365662712271863, 'KL = ', 19.330979619253281, 'epsilon = ', 20.979444309926375)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# trajectory optimization is finished Traj estimated cost is 30.250394281
# policy optimization start!!
# epoch 1, Training Loss= 0.000823
# epoch 11, Training Loss= 0.000694
# epoch 21, Training Loss= 0.000721
# epoch 31, Training Loss= 0.000722
# epoch 41, Training Loss= 0.000702
# epoch 51, Training Loss= 0.000711
# epoch 61, Training Loss= 0.000688
# epoch 71, Training Loss= 0.000697
# epoch 81, Training Loss= 0.000703
# epoch 91, Training Loss= 0.000673
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 30.4375745579
# ('epsilon is', 35.283767192343568)
# test starts
# mean value of real cost is 25.7844265016
# mean value of real cost is 32.1716712338
# mean value of real cost is 32.1635846596
# SUCCEESS : cost change < tolFun

# %%
# i=4
np.savetxt('w1.txt',W1_save[i,:,:])
np.savetxt('w2.txt',W2_save[i,:,:])
np.savetxt('w3.txt',W3_save[i,:,:])
np.savetxt('b1.txt',b1_save[i,:])
np.savetxt('b2.txt',b2_save[i,:])
np.savetxt('b3.txt',b3_save[i,:])
# np.savetxt('var.txt',var_save[i,:,:])
