# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
# import model
# import cost
# import iLQR
# import poliOpt
# import trajOpt
# import policyClass
# import modelLearn
# from gps_util import getCostNN, getCostAppNN, getCostTraj, getObs, getDesired
from mdgps import mdGPS

# %%
myGPS = mdGPS('hi')
W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
# Out:
# initial trajectories from iLQR
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           471.875     213         213         1.6         0.0
# ('sample generation cost = ', 309.76490527677458)
# ('sample generation cost = ', 544.93811340548154)
# ('sample generation cost = ', 533.48502793271405)
# ('sample generation cost = ', 390.61151502557118)
# ('sample generation cost = ', 383.62008970811996)
# ('sample generation cost = ', 458.44157887000551)
# ('sample generation cost = ', 378.61321127628139)
# ('sample generation cost = ', 368.17258834620191)
# ('sample generation cost = ', 456.06998934745036)
# ('sample generation cost = ', 626.42936292540116)
# ('sample generation cost = ', 408.34378915302199)
# ('sample generation cost = ', 417.71711489994152)
# ('sample generation cost = ', 388.43112172792013)
# ('sample generation cost = ', 303.63312649304481)
# ('sample generation cost = ', 707.18995491330111)
# ('sample generation cost = ', 871.21222034187849)
# ('sample generation cost = ', 479.92306271464867)
# ('sample generation cost = ', 567.33339816704449)
# ('sample generation cost = ', 571.49985722808481)
# ('sample generation cost = ', 417.89529424529059)
# initial policy optimization starts!!
# epoch 1, Training Loss= 2.155389
# epoch 11, Training Loss= 2.037605
# epoch 21, Training Loss= 2.077805
# epoch 31, Training Loss= 2.078081
# epoch 41, Training Loss= 2.086496
# epoch 51, Training Loss= 2.008067
# epoch 61, Training Loss= 2.067085
# epoch 71, Training Loss= 2.073918
# epoch 81, Training Loss= 2.045276
# epoch 91, Training Loss= 2.081989
# Optimization - policy mean is done
# Optimization - policy variance is done
# initial policy parameter is updated true cost is  10000.0
# ======================== Mirror descent GPS ============================
# iteration =  1
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 431.368344283
# mean value of real cost is 624.739666644
# mean value of real cost is 538.703976557
# mean value of real cost is 470.185115446
# mean value of real cost is 371.560709526
# mean value of real cost is 456.706957839
# mean value of real cost is 613.068426269
# mean value of real cost is 466.128483123
# mean value of real cost is 543.895979377
# mean value of real cost is 443.836379944
# mean value of real cost is 638.817981827
# mean value of real cost is 504.597798001
# mean value of real cost is 541.467496782
# mean value of real cost is 553.67641958
# mean value of real cost is 305.833410861
# mean value of real cost is 675.306641506
# mean value of real cost is 396.763268902
# mean value of real cost is 491.910349472
# mean value of real cost is 414.428390824
# mean value of real cost is 609.489968118
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 144.80191428866095, 'KL = ', 63.112871487548269, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 233.995634940326, 'KL = ', 3.5358590824028067, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 182.86645360545472, 'KL = ', 17.901656963906156, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 5.6234132519034912)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 208.90933584180084, 'KL = ', 8.2619300836817171, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 7.4989420933245592)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 221.82287801334917, 'KL = ', 5.4469841194400788, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 7.4989420933245592)
# trajectory optimization is finished Traj estimated cost is 221.822877264
# policy optimization start!!
# epoch 1, Training Loss= 0.472765
# epoch 11, Training Loss= 0.297091
# epoch 21, Training Loss= 0.282517
# epoch 31, Training Loss= 0.291709
# epoch 41, Training Loss= 0.279724
# epoch 51, Training Loss= 0.260769
# epoch 61, Training Loss= 0.268485
# epoch 71, Training Loss= 0.276971
# epoch 81, Training Loss= 0.266252
# epoch 91, Training Loss= 0.277785
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 307.119914702
# test starts
# mean value of real cost is 173.759030908
# iteration =  2
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 323.192921927
# mean value of real cost is 248.890645272
# mean value of real cost is 465.492450678
# mean value of real cost is 329.42361696
# mean value of real cost is 321.949223294
# mean value of real cost is 265.596649974
# mean value of real cost is 242.760813622
# mean value of real cost is 246.091646876
# mean value of real cost is 240.535550173
# mean value of real cost is 399.631704866
# mean value of real cost is 446.179470884
# mean value of real cost is 210.569579938
# mean value of real cost is 291.547204973
# mean value of real cost is 532.938586274
# mean value of real cost is 331.00687028
# mean value of real cost is 270.991517157
# mean value of real cost is 217.374829604
# mean value of real cost is 280.388154745
# mean value of real cost is 254.575258037
# mean value of real cost is 348.076757151
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 61.355708796795462, 'KL = ', 35.38256253118201, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 86.896718640318625, 'KL = ', 2.7503330190274577, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 69.90740105042866, 'KL = ', 9.7616625831692279, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 5.6234132519034912)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 77.33399676676359, 'KL = ', 5.1370112083922663, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 5.6234132519034912)
# trajectory optimization is finished Traj estimated cost is 77.3339966415
# policy optimization start!!
# epoch 1, Training Loss= 0.234701
# epoch 11, Training Loss= 0.154482
# epoch 21, Training Loss= 0.162416
# epoch 31, Training Loss= 0.164635
# epoch 41, Training Loss= 0.158502
# epoch 51, Training Loss= 0.159698
# epoch 61, Training Loss= 0.161302
# epoch 71, Training Loss= 0.167539
# epoch 81, Training Loss= 0.149738
# epoch 91, Training Loss= 0.143440
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 172.126430639
# ('epsilon is', 6.0602388916828396)
# test starts
# mean value of real cost is 81.2684786791
# iteration =  3
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 225.670595451
# mean value of real cost is 211.246169269
# mean value of real cost is 250.843217448
# mean value of real cost is 204.039522513
# mean value of real cost is 208.080327678
# mean value of real cost is 228.292338839
# mean value of real cost is 165.580301518
# mean value of real cost is 197.669606774
# mean value of real cost is 250.347262201
# mean value of real cost is 205.228160764
# mean value of real cost is 186.426816967
# mean value of real cost is 205.672541417
# mean value of real cost is 194.487450117
# mean value of real cost is 209.881484407
# mean value of real cost is 212.749462842
# mean value of real cost is 218.532633767
# mean value of real cost is 223.220984314
# mean value of real cost is 184.823519153
# mean value of real cost is 179.478813869
# mean value of real cost is 213.62207114
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 58.736861311805747, 'KL = ', 24.707538445874015, 'epsilon = ', 6.0602388916828396)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 69.264041004581813, 'KL = ', 0.91795315191822546, 'epsilon = ', 6.0602388916828396)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 62.853612775465201, 'KL = ', 5.1731554092118701, 'epsilon = ', 6.0602388916828396)
# ('KL < epsilon // eta = ', 1.7782794100389228)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 60.400296576737425, 'KL = ', 11.646124405326454, 'epsilon = ', 6.0602388916828396)
# ('PD is not satisfied // eta = ', 2.3713737056616555)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 61.532374048732244, 'KL = ', 7.808346925471481, 'epsilon = ', 6.0602388916828396)
# ('PD is not satisfied // eta = ', 2.7384196342643614)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 62.170846453602991, 'KL = ', 6.3640924843005848, 'epsilon = ', 6.0602388916828396)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# trajectory optimization is finished Traj estimated cost is 62.1708461444
# policy optimization start!!
# epoch 1, Training Loss= 0.065285
# epoch 11, Training Loss= 0.035179
# epoch 21, Training Loss= 0.032946
# epoch 31, Training Loss= 0.033748
# epoch 41, Training Loss= 0.032141
# epoch 51, Training Loss= 0.032255
# epoch 61, Training Loss= 0.033089
# epoch 71, Training Loss= 0.032714
# epoch 81, Training Loss= 0.030913
# epoch 91, Training Loss= 0.031919
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 82.2876537271
# ('epsilon is', 16.562198220915523)
# test starts
# mean value of real cost is 63.245018057
# iteration =  4
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 153.898664817
# mean value of real cost is 151.147501625
# mean value of real cost is 151.023174323
# mean value of real cost is 174.669771814
# mean value of real cost is 159.87908927
# mean value of real cost is 180.5854175
# mean value of real cost is 161.309607805
# mean value of real cost is 165.180645283
# mean value of real cost is 161.82132674
# mean value of real cost is 142.403171809
# mean value of real cost is 159.960425791
# mean value of real cost is 150.006674801
# mean value of real cost is 183.84951856
# mean value of real cost is 166.313143058
# mean value of real cost is 160.92805322
# mean value of real cost is 167.972847121
# mean value of real cost is 124.931830001
# mean value of real cost is 153.231230126
# mean value of real cost is 160.519597306
# mean value of real cost is 148.175156392
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 57.027701909669766, 'KL = ', 16.034981664677577, 'epsilon = ', 16.562198220915523)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1)
# trajectory optimization is finished Traj estimated cost is 57.0277039482
# policy optimization start!!
# epoch 1, Training Loss= 0.034662
# epoch 11, Training Loss= 0.017480
# epoch 21, Training Loss= 0.016110
# epoch 31, Training Loss= 0.015986
# epoch 41, Training Loss= 0.015460
# epoch 51, Training Loss= 0.014422
# epoch 61, Training Loss= 0.014397
# epoch 71, Training Loss= 0.014695
# epoch 81, Training Loss= 0.013816
# epoch 91, Training Loss= 0.013759
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 63.3713930414
# ('epsilon is', 32.974527056719353)
# test starts
# mean value of real cost is 57.5392353056
# iteration =  5
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 114.512797347
# mean value of real cost is 104.097480935
# mean value of real cost is 109.664900952
# mean value of real cost is 113.55799341
# mean value of real cost is 129.698911565
# mean value of real cost is 101.367709739
# mean value of real cost is 111.920007085
# mean value of real cost is 113.154847678
# mean value of real cost is 103.728968371
# mean value of real cost is 121.029429973
# mean value of real cost is 102.316148889
# mean value of real cost is 113.045491132
# mean value of real cost is 123.963114784
# mean value of real cost is 126.32616625
# mean value of real cost is 121.515452168
# mean value of real cost is 128.081513609
# mean value of real cost is 118.518899829
# mean value of real cost is 133.812384337
# mean value of real cost is 123.886501431
# mean value of real cost is 117.634202688
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 56.17879093155134, 'KL = ', 7.299103811924641, 'epsilon = ', 32.974527056719353)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.448506917458516, 'KL = ', 116.65826539571083, 'epsilon = ', 32.974527056719353)
# ('PD is not satisfied // eta = ', 0.31622776601683794)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.641752121824858, 'KL = ', 36.975803759436154, 'epsilon = ', 32.974527056719353)
# ('PD is not satisfied // eta = ', 0.56234132519034907)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.867404031386265, 'KL = ', 17.376881013228569, 'epsilon = ', 32.974527056719353)
# ('KL < epsilon // eta = ', 0.42169650342858228)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.742113627908161, 'KL = ', 25.730047873293916, 'epsilon = ', 32.974527056719353)
# ('KL < epsilon // eta = ', 0.36517412725483772)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.688785115401522, 'KL = ', 30.962377061706253, 'epsilon = ', 32.974527056719353)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# trajectory optimization is finished Traj estimated cost is 55.6887851254
# policy optimization start!!
# epoch 1, Training Loss= 0.009105
# epoch 11, Training Loss= 0.005414
# epoch 21, Training Loss= 0.005291
# epoch 31, Training Loss= 0.005373
# epoch 41, Training Loss= 0.005079
# epoch 51, Training Loss= 0.005033
# epoch 61, Training Loss= 0.004845
# epoch 71, Training Loss= 0.004917
# epoch 81, Training Loss= 0.004870
# epoch 91, Training Loss= 0.004748
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 57.4681353127
# ('epsilon is', 71.186201684042331)
# test starts
# mean value of real cost is 55.7194886747
# iteration =  6
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 89.024495694
# mean value of real cost is 102.220899773
# mean value of real cost is 91.7384541166
# mean value of real cost is 82.2423488627
# mean value of real cost is 96.1369914788
# mean value of real cost is 88.9625179314
# mean value of real cost is 78.87840596
# mean value of real cost is 104.122004894
# mean value of real cost is 72.9092462918
# mean value of real cost is 94.9655992817
# mean value of real cost is 89.0922965772
# mean value of real cost is 93.7992170591
# mean value of real cost is 99.4615785501
# mean value of real cost is 75.9118524463
# mean value of real cost is 101.012327616
# mean value of real cost is 98.9025997917
# mean value of real cost is 71.7354234407
# mean value of real cost is 73.0605494484
# mean value of real cost is 87.0073974302
# mean value of real cost is 92.7229977585
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.554603228003501, 'KL = ', 2.0946534176963043, 'epsilon = ', 71.186201684042331)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.328813036391033, 'KL = ', 59.990841329132728, 'epsilon = ', 71.186201684042331)
# ('KL < epsilon // eta = ', 0.010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.299773802185236, 'KL = ', 303.31843133166683, 'epsilon = ', 71.186201684042331)
# ('PD is not satisfied // eta = ', 0.031622776601683798)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.303727308562003, 'KL = ', 160.70504866638018, 'epsilon = ', 71.186201684042331)
# ('PD is not satisfied // eta = ', 0.056234132519034911)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.311309800734954, 'KL = ', 103.62929937924244, 'epsilon = ', 71.186201684042331)
# ('PD is not satisfied // eta = ', 0.074989420933245593)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.318396494385546, 'KL = ', 80.007949900507285, 'epsilon = ', 71.186201684042331)
# ('PD is not satisfied // eta = ', 0.086596432336006543)
# SUCCEESS: cost change < tolFun
# ('cost = ', 55.323130732833775, 'KL = ', 69.541869286140127, 'epsilon = ', 71.186201684042331)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.086596432336006543)
# trajectory optimization is finished Traj estimated cost is 55.3283885111
# policy optimization start!!
# epoch 1, Training Loss= 0.002493
# epoch 11, Training Loss= 0.001631
# epoch 21, Training Loss= 0.001499
# epoch 31, Training Loss= 0.001493
# epoch 41, Training Loss= 0.001343
# epoch 51, Training Loss= 0.001358
# epoch 61, Training Loss= 0.001326
# epoch 71, Training Loss= 0.001296
# epoch 81, Training Loss= 0.001243
# epoch 91, Training Loss= 0.001527
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 55.7211920255
# ('epsilon is', 193.88885509557238)
# test starts
# mean value of real cost is 55.3578891317
# iteration =  7
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 57.4062484999
# mean value of real cost is 68.6389139252
# mean value of real cost is 66.0693255094
# mean value of real cost is 60.9252812449
# mean value of real cost is 58.5444273011
# mean value of real cost is 80.539075096
# mean value of real cost is 54.8256506158
# mean value of real cost is 50.1285732318
# mean value of real cost is 81.6689017487
# mean value of real cost is 58.6966794882
# mean value of real cost is 61.200580617
# mean value of real cost is 63.6463727312
# mean value of real cost is 49.2001931273
# mean value of real cost is 65.3252982962
# mean value of real cost is 68.8842665977
# mean value of real cost is 71.1037252653
# mean value of real cost is 65.7995638639
# mean value of real cost is 50.2576104426
# mean value of real cost is 68.5386156331
# mean value of real cost is 63.2780325522
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.324607097285288, 'KL = ', 0.24500574393778676, 'epsilon = ', 193.88885509557238)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.290136304510142, 'KL = ', 13.99143493084329, 'epsilon = ', 193.88885509557238)
# ('KL < epsilon // eta = ', 0.010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.269483553998136, 'KL = ', 161.66232724442011, 'epsilon = ', 193.88885509557238)
# ('KL < epsilon // eta = ', 0.0010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.268532097141346, 'KL = ', 466.82651111029145, 'epsilon = ', 193.88885509557238)
# ('PD is not satisfied // eta = ', 0.0031622776601683798)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.268635302460766, 'KL = ', 304.58198502600362, 'epsilon = ', 193.88885509557238)
# ('PD is not satisfied // eta = ', 0.0056234132519034918)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.268861202281919, 'KL = ', 229.48771546187248, 'epsilon = ', 193.88885509557238)
# ('PD is not satisfied // eta = ', 0.0074989420933245596)
# SUCCEESS: cost change < tolFun
# ('cost = ', 55.269097555192218, 'KL = ', 194.47127622178775, 'epsilon = ', 193.88885509557238)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.0074989420933245596)
# trajectory optimization is finished Traj estimated cost is 55.2693957274
# policy optimization start!!
# epoch 1, Training Loss= 0.001374
# epoch 11, Training Loss= 0.000881
# epoch 21, Training Loss= 0.000814
# epoch 31, Training Loss= 0.000792
# epoch 41, Training Loss= 0.000721
# epoch 51, Training Loss= 0.000725
# epoch 61, Training Loss= 0.000655
# epoch 71, Training Loss= 0.000620
# epoch 81, Training Loss= 0.000745
# epoch 91, Training Loss= 0.000759
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 55.3331685782
# ('epsilon is', 686.79905269707137)
# test starts
# mean value of real cost is 55.2787870068
# iteration =  8
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 47.8263193146
# mean value of real cost is 40.5266952059
# mean value of real cost is 52.1672400052
# mean value of real cost is 54.1782313481
# mean value of real cost is 51.4739328872
# mean value of real cost is 61.9580988315
# mean value of real cost is 58.5690588405
# mean value of real cost is 46.0659574799
# mean value of real cost is 60.3311134309
# mean value of real cost is 54.0961846541
# mean value of real cost is 51.8522004315
# mean value of real cost is 72.1069535524
# mean value of real cost is 62.2575072386
# mean value of real cost is 67.0240537109
# mean value of real cost is 56.6950384397
# mean value of real cost is 69.7492364736
# mean value of real cost is 66.3002410344
# mean value of real cost is 64.4368593895
# mean value of real cost is 54.2703791375
# mean value of real cost is 51.2975733857
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.271896076698994, 'KL = ', 0.0033541240964172778, 'epsilon = ', 686.79905269707137)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS: cost change < tolFun
# ('cost = ', 55.271078093752578, 'KL = ', 0.31005641257209998, 'epsilon = ', 686.79905269707137)
# ('KL < epsilon // eta = ', 0.010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.267322319636655, 'KL = ', 16.761130291303303, 'epsilon = ', 686.79905269707137)
# ('KL < epsilon // eta = ', 0.0010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.264989113670673, 'KL = ', 175.57056961810122, 'epsilon = ', 686.79905269707137)
# ('KL < epsilon // eta = ', 0.00010000000000000003)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.264878038230393, 'KL = ', 484.96751957016886, 'epsilon = ', 686.79905269707137)
# ('KL < epsilon // eta = ', 1.0000000000000004e-05)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.264878038230393, 'KL = ', 826.33873967525915, 'epsilon = ', 686.79905269707137)
# ('PD is not satisfied // eta = ', 3.1622776601683802e-05)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.264878038230393, 'KL = ', 654.61726415362273, 'epsilon = ', 686.79905269707137)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.1622776601683802e-05)
# trajectory optimization is finished Traj estimated cost is 55.2648767421
# policy optimization start!!
# epoch 1, Training Loss= 0.000762
# epoch 11, Training Loss= 0.000720
# epoch 21, Training Loss= 0.000707
# epoch 31, Training Loss= 0.000667
# epoch 41, Training Loss= 0.000606
# epoch 51, Training Loss= 0.000745
# epoch 61, Training Loss= 0.000650
# epoch 71, Training Loss= 0.000539
# epoch 81, Training Loss= 0.000674
# epoch 91, Training Loss= 0.000680
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 55.2719971223
# ('epsilon is', 3293.5578803057647)
# test starts
# mean value of real cost is 55.2740370745
# iteration =  9
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 65.3435828982
# mean value of real cost is 60.4021950891
# mean value of real cost is 52.4856605207
# mean value of real cost is 54.5674462168
# mean value of real cost is 55.1628977893
# mean value of real cost is 46.1508404092
# mean value of real cost is 49.277816097
# mean value of real cost is 62.5216583743
# mean value of real cost is 71.757327198
# mean value of real cost is 46.4777631722
# mean value of real cost is 67.3521076868
# mean value of real cost is 49.4462947586
# mean value of real cost is 39.820631532
# mean value of real cost is 53.94747569
# mean value of real cost is 61.0632311194
# mean value of real cost is 53.4435809871
# mean value of real cost is 45.338193701
# mean value of real cost is 47.0573746262
# mean value of real cost is 42.0861357977
# mean value of real cost is 45.3215165026
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.272293929741195, 'KL = ', 3.9922860935093278e-07, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.272293929741195, 'KL = ', 7.8378364131284411e-06, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 0.010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.272293929741195, 'KL = ', 0.00074880376756439456, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 0.0010000000000000002)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.271699183985476, 'KL = ', 0.36140497894096973, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 0.00010000000000000003)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.268713273684519, 'KL = ', 19.721002046877924, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 1.0000000000000004e-05)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.265064349200536, 'KL = ', 228.23502801134072, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 3.16227766016838e-06)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.264722266127642, 'KL = ', 405.96623032865932, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 1.7782794100389229e-06)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.26468433512759, 'KL = ', 495.95316598273678, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 1.3335214321633241e-06)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.26468433512759, 'KL = ', 535.17613265627767, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 1.1547819846894582e-06)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 55.26468433512759, 'KL = ', 555.15260262440006, 'epsilon = ', 1000)
# ('KL < epsilon // eta = ', 1.0746078283213176e-06)
# trajectory optimization is finished Traj estimated cost is 55.2646731656
# policy optimization start!!
# epoch 1, Training Loss= 0.000426
# epoch 11, Training Loss= 0.000512
# epoch 21, Training Loss= 0.000321
# epoch 31, Training Loss= 0.000389
# epoch 41, Training Loss= 0.000411
# epoch 51, Training Loss= 0.000426
# epoch 61, Training Loss= 0.000473
# epoch 71, Training Loss= 0.000346
# epoch 81, Training Loss= 0.000340
# epoch 91, Training Loss= 0.000280
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 55.2722945779
# ('epsilon is', 480.48553308115675)
# test starts
# mean value of real cost is 55.2685845408
# SUCCEESS : cost change < tolFun

# %%
# i=4
np.savetxt('w1.txt',W1_save[i,:,:])
np.savetxt('w2.txt',W2_save[i,:,:])
np.savetxt('w3.txt',W3_save[i,:,:])
np.savetxt('b1.txt',b1_save[i,:])
np.savetxt('b2.txt',b2_save[i,:])
np.savetxt('b3.txt',b3_save[i,:])
# np.savetxt('var.txt',var_save[i,:,:])
