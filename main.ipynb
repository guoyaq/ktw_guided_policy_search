# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
# import model
# import cost
# import iLQR
# import poliOpt
# import trajOpt
# import policyClass
# import modelLearn
# from gps_util import getCostNN, getCostAppNN, getCostTraj, getObs, getDesired
from mdgps import mdGPS

# %%
myGPS = mdGPS('hi')
W1_save, W2_save, W3_save, b1_save, b2_save, b3_save, var_save, i ,cost_real = myGPS.update()
# Out:
# initial trajectories from iLQR
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           120.8       95.1        95.1        1.07        0.0
# 1           25.6977     2.36e-09    2.32e-09    4.24e-06    -0.2
# SUCCEESS: cost change < tolFun
# ('sample generation cost = ', 191.31151966613544)
# ('sample generation cost = ', 164.08158701555277)
# ('sample generation cost = ', 187.073148521061)
# ('sample generation cost = ', 155.30867074238745)
# ('sample generation cost = ', 170.8897227163975)
# ('sample generation cost = ', 186.40780145200461)
# ('sample generation cost = ', 183.41384334296703)
# ('sample generation cost = ', 189.24732172288179)
# ('sample generation cost = ', 189.64345163209148)
# ('sample generation cost = ', 202.97911666498979)
# ('sample generation cost = ', 186.28238575547013)
# ('sample generation cost = ', 212.60755329642808)
# ('sample generation cost = ', 173.91653647460723)
# ('sample generation cost = ', 184.85442221459567)
# ('sample generation cost = ', 167.0705685679232)
# ('sample generation cost = ', 191.26146305475731)
# ('sample generation cost = ', 194.08723110335524)
# ('sample generation cost = ', 204.61299404949023)
# ('sample generation cost = ', 184.41240844992345)
# ('sample generation cost = ', 182.09121400475004)
# initial policy optimization starts!!
# epoch 1, Training Loss= 2.014548
# epoch 11, Training Loss= 1.936674
# epoch 21, Training Loss= 1.998580
# epoch 31, Training Loss= 2.012940
# epoch 41, Training Loss= 2.004700
# epoch 51, Training Loss= 2.044473
# epoch 61, Training Loss= 2.009234
# epoch 71, Training Loss= 2.004901
# epoch 81, Training Loss= 2.004580
# epoch 91, Training Loss= 1.980295
# Optimization - policy mean is done
# Optimization - policy variance is done
# initial policy parameter is updated true cost is  10000.0
# ======================== Mirror descent GPS ============================
# iteration =  1
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 179.924041693
# mean value of real cost is 189.428555044
# mean value of real cost is 179.130047129
# mean value of real cost is 182.536775575
# mean value of real cost is 189.699151948
# mean value of real cost is 214.603611212
# mean value of real cost is 183.542700651
# mean value of real cost is 169.476271645
# mean value of real cost is 169.71429418
# mean value of real cost is 182.765312037
# mean value of real cost is 163.630410203
# mean value of real cost is 174.796665058
# mean value of real cost is 173.250674265
# mean value of real cost is 194.233107774
# mean value of real cost is 177.36239856
# mean value of real cost is 181.465947326
# mean value of real cost is 186.420475203
# mean value of real cost is 184.205836461
# mean value of real cost is 172.739294801
# mean value of real cost is 200.785693845
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.974280751756393, 'KL = ', 30.479708284193677, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 30.808642526699732, 'KL = ', 0.76658331442421779, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 28.647714371136715, 'KL = ', 5.7145616864617761, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 5.6234132519034912)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 29.765588275551483, 'KL = ', 2.1591455277402067, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 4.2169650342858223)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 29.202806681630324, 'KL = ', 3.5446787537450919, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.6517412725483771)
# SUCCEESS: cost change < tolFun
# ('cost = ', 28.922456916781268, 'KL = ', 4.5116473472917056, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.6517412725483771)
# (1, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 220.602168915
# mean value of real cost is 204.771339017
# mean value of real cost is 189.891908166
# mean value of real cost is 197.117569226
# mean value of real cost is 199.691826174
# mean value of real cost is 200.880035668
# mean value of real cost is 202.330348741
# mean value of real cost is 190.59412799
# mean value of real cost is 181.280981438
# mean value of real cost is 196.196823292
# mean value of real cost is 202.147148377
# mean value of real cost is 225.664308709
# mean value of real cost is 199.322079974
# mean value of real cost is 191.045752194
# mean value of real cost is 201.241331503
# mean value of real cost is 199.392189153
# mean value of real cost is 210.162795794
# mean value of real cost is 188.554629394
# mean value of real cost is 179.006358587
# mean value of real cost is 203.367844518
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 3.6517412725483771)
# SUCCEESS: cost change < tolFun
# ('cost = ', 37.012184112863423, 'KL = ', 4.6014058667642388, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.6517412725483771)
# (2, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 169.114017102
# mean value of real cost is 167.805370584
# mean value of real cost is 198.542599801
# mean value of real cost is 210.040374336
# mean value of real cost is 185.284106002
# mean value of real cost is 211.886504392
# mean value of real cost is 162.52034388
# mean value of real cost is 199.928419301
# mean value of real cost is 193.897766054
# mean value of real cost is 216.667532188
# mean value of real cost is 182.988899119
# mean value of real cost is 184.415607226
# mean value of real cost is 186.910990118
# mean value of real cost is 183.844485128
# mean value of real cost is 216.765076595
# mean value of real cost is 204.164062588
# mean value of real cost is 173.20372432
# mean value of real cost is 197.198658115
# mean value of real cost is 227.775259185
# mean value of real cost is 178.258822658
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 3.6517412725483771)
# SUCCEESS: cost change < tolFun
# ('cost = ', 36.084522674765651, 'KL = ', 4.591780163495133, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 3.6517412725483771)
# trajectory optimization is finished Traj estimated cost is 33.90455565
# policy optimization start!!
# epoch 1, Training Loss= 0.021252
# epoch 11, Training Loss= 0.007784
# epoch 21, Training Loss= 0.007310
# epoch 31, Training Loss= 0.007351
# epoch 41, Training Loss= 0.006947
# epoch 51, Training Loss= 0.007007
# epoch 61, Training Loss= 0.007155
# epoch 71, Training Loss= 0.007254
# epoch 81, Training Loss= 0.006793
# epoch 91, Training Loss= 0.007047
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 38.7143562994
# test starts
# mean value of real cost is 28.4482353338
# mean value of real cost is 35.8969103827
# mean value of real cost is 35.0726160739
# iteration =  2
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 142.639358886
# mean value of real cost is 150.221333464
# mean value of real cost is 139.058382635
# mean value of real cost is 164.66039233
# mean value of real cost is 126.044796603
# mean value of real cost is 148.028891883
# mean value of real cost is 148.858094985
# mean value of real cost is 140.309511691
# mean value of real cost is 152.235806023
# mean value of real cost is 138.330011115
# mean value of real cost is 140.672663661
# mean value of real cost is 132.126869897
# mean value of real cost is 153.06703761
# mean value of real cost is 151.331284542
# mean value of real cost is 139.809030743
# mean value of real cost is 148.02523322
# mean value of real cost is 158.847206881
# mean value of real cost is 141.872095185
# mean value of real cost is 165.881155132
# mean value of real cost is 174.310650742
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.970273569586556, 'KL = ', 21.693845855155736, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 28.757703694529525, 'KL = ', 0.45007662882049104, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.9071370025863, 'KL = ', 3.6324973588669582, 'epsilon = ', 5)
# ('KL < epsilon // eta = ', 1.7782794100389228)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.403255386317554, 'KL = ', 9.3306200555668433, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 2.3713737056616555)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.652599207953383, 'KL = ', 5.8859473064124632, 'epsilon = ', 5)
# ('PD is not satisfied // eta = ', 2.7384196342643614)
# SUCCEESS: cost change < tolFun
# ('cost = ', 27.780053756253508, 'KL = ', 4.635721967571639, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# (1, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 161.678077959
# mean value of real cost is 157.483674934
# mean value of real cost is 162.168553143
# mean value of real cost is 148.870036149
# mean value of real cost is 157.916589742
# mean value of real cost is 146.207770173
# mean value of real cost is 167.62816829
# mean value of real cost is 157.473241636
# mean value of real cost is 154.416197236
# mean value of real cost is 165.718201984
# mean value of real cost is 156.349883684
# mean value of real cost is 140.767438156
# mean value of real cost is 156.961941535
# mean value of real cost is 150.703793848
# mean value of real cost is 145.628346767
# mean value of real cost is 148.391075856
# mean value of real cost is 139.615011685
# mean value of real cost is 140.230428131
# mean value of real cost is 137.164746009
# mean value of real cost is 142.929788697
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 2.7384196342643614)
# SUCCEESS: cost change < tolFun
# ('cost = ', 34.573638031661652, 'KL = ', 4.7012930029620241, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# (2, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 154.865016694
# mean value of real cost is 154.253650893
# mean value of real cost is 143.031164983
# mean value of real cost is 169.92822095
# mean value of real cost is 151.226012489
# mean value of real cost is 153.466595584
# mean value of real cost is 168.180414525
# mean value of real cost is 144.035016491
# mean value of real cost is 136.81756829
# mean value of real cost is 149.138115382
# mean value of real cost is 169.900270829
# mean value of real cost is 143.903781443
# mean value of real cost is 161.77202112
# mean value of real cost is 153.003287691
# mean value of real cost is 162.854739257
# mean value of real cost is 167.725621521
# mean value of real cost is 160.107052099
# mean value of real cost is 164.38825681
# mean value of real cost is 152.146816852
# mean value of real cost is 146.075276244
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 2.7384196342643614)
# SUCCEESS: cost change < tolFun
# ('cost = ', 34.487327665733808, 'KL = ', 4.6626999161516132, 'epsilon = ', 5)
# =================== dual gradient descent is converged ===================
# ('eta = ', 2.7384196342643614)
# trajectory optimization is finished Traj estimated cost is 32.3229302717
# policy optimization start!!
# epoch 1, Training Loss= 0.003461
# epoch 11, Training Loss= 0.002630
# epoch 21, Training Loss= 0.002546
# epoch 31, Training Loss= 0.002533
# epoch 41, Training Loss= 0.002467
# epoch 51, Training Loss= 0.002477
# epoch 61, Training Loss= 0.002447
# epoch 71, Training Loss= 0.002383
# epoch 81, Training Loss= 0.002427
# epoch 91, Training Loss= 0.002384
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 34.1435808027
# ('epsilon is', 8.7762944054134113)
# test starts
# mean value of real cost is 27.2664267256
# mean value of real cost is 34.0294138536
# mean value of real cost is 33.7480606311
# iteration =  3
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 112.458858785
# mean value of real cost is 101.218235469
# mean value of real cost is 129.210991732
# mean value of real cost is 119.48749715
# mean value of real cost is 137.493099345
# mean value of real cost is 114.327901294
# mean value of real cost is 115.462371013
# mean value of real cost is 124.299007859
# mean value of real cost is 112.313543277
# mean value of real cost is 112.698987572
# mean value of real cost is 121.681395281
# mean value of real cost is 118.424815405
# mean value of real cost is 123.891845175
# mean value of real cost is 112.906698061
# mean value of real cost is 122.739766377
# mean value of real cost is 129.179164039
# mean value of real cost is 127.635788324
# mean value of real cost is 129.902487384
# mean value of real cost is 126.958415974
# mean value of real cost is 126.279050115
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.599723597101558, 'KL = ', 15.005304388340877, 'epsilon = ', 8.7762944054134113)
# ('PD is not satisfied // eta = ', 10.0)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.473572501465188, 'KL = ', 0.26970117398262583, 'epsilon = ', 8.7762944054134113)
# ('KL < epsilon // eta = ', 3.1622776601683795)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 27.116190849023255, 'KL = ', 2.2883496789563109, 'epsilon = ', 8.7762944054134113)
# ('KL < epsilon // eta = ', 1.7782794100389228)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.860215229975275, 'KL = ', 6.1272435842574717, 'epsilon = ', 8.7762944054134113)
# ('KL < epsilon // eta = ', 1.333521432163324)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.727030477480067, 'KL = ', 9.7118413177244545, 'epsilon = ', 8.7762944054134113)
# ('PD is not satisfied // eta = ', 1.5399265260594919)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.79334490023966, 'KL = ', 7.7373208377333924, 'epsilon = ', 8.7762944054134113)
# ('KL < epsilon // eta = ', 1.4330125702369627)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.7600606367442, 'KL = ', 8.6751739588391779, 'epsilon = ', 8.7762944054134113)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1.4330125702369627)
# (1, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 125.348174688
# mean value of real cost is 126.610929363
# mean value of real cost is 119.304893086
# mean value of real cost is 131.3720965
# mean value of real cost is 130.083325239
# mean value of real cost is 131.419750673
# mean value of real cost is 131.943213625
# mean value of real cost is 110.481908045
# mean value of real cost is 126.671049872
# mean value of real cost is 125.78236905
# mean value of real cost is 130.151413996
# mean value of real cost is 137.662128804
# mean value of real cost is 130.19431679
# mean value of real cost is 129.767432898
# mean value of real cost is 126.879136972
# mean value of real cost is 139.005904549
# mean value of real cost is 138.162820221
# mean value of real cost is 120.730009036
# mean value of real cost is 125.297052087
# mean value of real cost is 144.427555651
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1.4330125702369627)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 33.393718993084157, 'KL = ', 8.7427355383507912, 'epsilon = ', 8.7762944054134113)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1.4330125702369627)
# (2, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 119.854727791
# mean value of real cost is 134.671803244
# mean value of real cost is 123.57859584
# mean value of real cost is 125.810202339
# mean value of real cost is 135.063685643
# mean value of real cost is 134.628051103
# mean value of real cost is 123.537868483
# mean value of real cost is 125.8519606
# mean value of real cost is 135.4396155
# mean value of real cost is 126.232290172
# mean value of real cost is 121.549898339
# mean value of real cost is 123.187110403
# mean value of real cost is 111.600854381
# mean value of real cost is 125.907490099
# mean value of real cost is 132.919176017
# mean value of real cost is 122.260511586
# mean value of real cost is 109.77731019
# mean value of real cost is 130.573855213
# mean value of real cost is 130.84262771
# mean value of real cost is 130.544500815
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1.4330125702369627)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 33.339434628231992, 'KL = ', 8.7160483321615114, 'epsilon = ', 8.7762944054134113)
# =================== dual gradient descent is converged ===================
# ('eta = ', 1.4330125702369627)
# trajectory optimization is finished Traj estimated cost is 31.1533098191
# policy optimization start!!
# epoch 1, Training Loss= 0.002298
# epoch 11, Training Loss= 0.001778
# epoch 21, Training Loss= 0.001773
# epoch 31, Training Loss= 0.001756
# epoch 41, Training Loss= 0.001706
# epoch 51, Training Loss= 0.001757
# epoch 61, Training Loss= 0.001684
# epoch 71, Training Loss= 0.001674
# epoch 81, Training Loss= 0.001700
# epoch 91, Training Loss= 0.001686
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 32.2258304834
# ('epsilon is', 12.234495510402938)
# test starts
# mean value of real cost is 26.4059078785
# mean value of real cost is 32.968216097
# mean value of real cost is 32.8186330298
# iteration =  4
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 99.0119099244
# mean value of real cost is 100.990332204
# mean value of real cost is 84.9560182717
# mean value of real cost is 92.7445632129
# mean value of real cost is 101.88654823
# mean value of real cost is 97.5019070228
# mean value of real cost is 91.0224171203
# mean value of real cost is 94.5911534465
# mean value of real cost is 93.8603019691
# mean value of real cost is 115.14212764
# mean value of real cost is 85.3591694933
# mean value of real cost is 93.1816099931
# mean value of real cost is 88.4785140317
# mean value of real cost is 89.7596109594
# mean value of real cost is 86.64906894
# mean value of real cost is 81.6346087643
# mean value of real cost is 94.12011903
# mean value of real cost is 78.6310502224
# mean value of real cost is 98.5949670358
# mean value of real cost is 90.4097299504
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.349316481459052, 'KL = ', 8.6510863432188092, 'epsilon = ', 12.234495510402938)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.086604038163983, 'KL = ', 128.86426185728715, 'epsilon = ', 12.234495510402938)
# ('PD is not satisfied // eta = ', 0.31622776601683794)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.159633836513304, 'KL = ', 42.629955918265694, 'epsilon = ', 12.234495510402938)
# ('PD is not satisfied // eta = ', 0.56234132519034907)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.241313719654585, 'KL = ', 20.383211321903062, 'epsilon = ', 12.234495510402938)
# ('PD is not satisfied // eta = ', 0.74989420933245587)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.29311167251732, 'KL = ', 13.464593997096248, 'epsilon = ', 12.234495510402938)
# ('PD is not satisfied // eta = ', 0.86596432336006535)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.32084658730173, 'KL = ', 10.828393891541129, 'epsilon = ', 12.234495510402938)
# ('KL < epsilon // eta = ', 0.80584218776148187)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.306863142685426, 'KL = ', 12.084945671817589, 'epsilon = ', 12.234495510402938)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.80584218776148187)
# (1, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 111.260976886
# mean value of real cost is 90.6730792151
# mean value of real cost is 101.969473417
# mean value of real cost is 100.364614447
# mean value of real cost is 99.7442081663
# mean value of real cost is 100.304046321
# mean value of real cost is 94.4758969391
# mean value of real cost is 107.206196405
# mean value of real cost is 95.4306300858
# mean value of real cost is 90.2101777126
# mean value of real cost is 109.319745531
# mean value of real cost is 97.7300609146
# mean value of real cost is 92.0820930396
# mean value of real cost is 84.8816957646
# mean value of real cost is 105.242487175
# mean value of real cost is 94.9659483396
# mean value of real cost is 89.2533918424
# mean value of real cost is 98.6647156048
# mean value of real cost is 97.5796897312
# mean value of real cost is 90.3275630596
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.80584218776148187)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.740404472356396, 'KL = ', 12.138959455030587, 'epsilon = ', 12.234495510402938)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.80584218776148187)
# (2, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 100.004555483
# mean value of real cost is 100.71663494
# mean value of real cost is 94.689398319
# mean value of real cost is 102.275060081
# mean value of real cost is 107.20621462
# mean value of real cost is 97.902402774
# mean value of real cost is 90.146667832
# mean value of real cost is 85.3825696544
# mean value of real cost is 100.978695921
# mean value of real cost is 108.034690712
# mean value of real cost is 92.8687641142
# mean value of real cost is 94.9604111004
# mean value of real cost is 95.2089929084
# mean value of real cost is 101.944323958
# mean value of real cost is 97.3035806307
# mean value of real cost is 98.7119444223
# mean value of real cost is 97.7523807208
# mean value of real cost is 93.7092780067
# mean value of real cost is 86.4781479501
# mean value of real cost is 104.694592318
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.80584218776148187)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.718712990694925, 'KL = ', 12.121457937851771, 'epsilon = ', 12.234495510402938)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.80584218776148187)
# trajectory optimization is finished Traj estimated cost is 30.5840916848
# policy optimization start!!
# epoch 1, Training Loss= 0.001630
# epoch 11, Training Loss= 0.001362
# epoch 21, Training Loss= 0.001354
# epoch 31, Training Loss= 0.001354
# epoch 41, Training Loss= 0.001349
# epoch 51, Training Loss= 0.001293
# epoch 61, Training Loss= 0.001334
# epoch 71, Training Loss= 0.001330
# epoch 81, Training Loss= 0.001343
# epoch 91, Training Loss= 0.001288
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 31.1098726552
# ('epsilon is', 19.100963226252599)
# test starts
# mean value of real cost is 26.0203096619
# mean value of real cost is 32.4658159414
# mean value of real cost is 32.3878079974
# iteration =  5
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 80.8081759147
# mean value of real cost is 74.227573834
# mean value of real cost is 65.3685049451
# mean value of real cost is 72.2932687667
# mean value of real cost is 75.5305397293
# mean value of real cost is 73.6380677065
# mean value of real cost is 70.6888760882
# mean value of real cost is 66.5988835125
# mean value of real cost is 79.2062741009
# mean value of real cost is 65.3924710547
# mean value of real cost is 71.7632301676
# mean value of real cost is 66.0223865391
# mean value of real cost is 70.7431885307
# mean value of real cost is 68.5126257262
# mean value of real cost is 57.2729106905
# mean value of real cost is 64.8714236414
# mean value of real cost is 70.9629841608
# mean value of real cost is 62.3084603098
# mean value of real cost is 70.564934538
# mean value of real cost is 65.3595842197
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.091895886915282, 'KL = ', 4.2570617899596819, 'epsilon = ', 19.100963226252599)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.929766165372964, 'KL = ', 90.034864463680577, 'epsilon = ', 19.100963226252599)
# ('PD is not satisfied // eta = ', 0.31622776601683794)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.988632790619455, 'KL = ', 24.837200053026095, 'epsilon = ', 19.100963226252599)
# ('PD is not satisfied // eta = ', 0.56234132519034907)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 26.038587256132864, 'KL = ', 10.836846979710181, 'epsilon = ', 19.100963226252599)
# ('KL < epsilon // eta = ', 0.42169650342858228)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.012478069482214, 'KL = ', 16.645997578397473, 'epsilon = ', 19.100963226252599)
# ('KL < epsilon // eta = ', 0.36517412725483772)
# SUCCEESS: cost change < tolFun
# ('cost = ', 26.000194137356672, 'KL = ', 20.410023233164431, 'epsilon = ', 19.100963226252599)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# (1, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 83.7405784062
# mean value of real cost is 87.2072331111
# mean value of real cost is 79.7397237951
# mean value of real cost is 76.5836143627
# mean value of real cost is 77.6414373237
# mean value of real cost is 77.7312178321
# mean value of real cost is 77.940210972
# mean value of real cost is 85.5495228204
# mean value of real cost is 79.2461768804
# mean value of real cost is 73.1723804109
# mean value of real cost is 74.1803586288
# mean value of real cost is 76.2874457076
# mean value of real cost is 82.6975450877
# mean value of real cost is 67.029194745
# mean value of real cost is 77.4791698448
# mean value of real cost is 66.3174132048
# mean value of real cost is 64.9189912646
# mean value of real cost is 72.1803054058
# mean value of real cost is 80.9627070626
# mean value of real cost is 73.2529867594
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.36517412725483772)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.428172955219637, 'KL = ', 20.502540174147207, 'epsilon = ', 19.100963226252599)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# (2, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 72.7935636406
# mean value of real cost is 77.3042648264
# mean value of real cost is 87.8731037609
# mean value of real cost is 69.4761102635
# mean value of real cost is 80.5370071661
# mean value of real cost is 71.2522963175
# mean value of real cost is 72.3157726883
# mean value of real cost is 77.9333547433
# mean value of real cost is 76.3980002432
# mean value of real cost is 77.518065118
# mean value of real cost is 73.1895369621
# mean value of real cost is 75.1323680868
# mean value of real cost is 89.1568451237
# mean value of real cost is 78.3776571216
# mean value of real cost is 73.6832759302
# mean value of real cost is 67.6391246802
# mean value of real cost is 72.6039863786
# mean value of real cost is 64.1869873463
# mean value of real cost is 73.9900472919
# mean value of real cost is 83.4275913472
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.36517412725483772)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.397533594579784, 'KL = ', 20.422597243635437, 'epsilon = ', 19.100963226252599)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.36517412725483772)
# trajectory optimization is finished Traj estimated cost is 30.2714025394
# policy optimization start!!
# epoch 1, Training Loss= 0.000849
# epoch 11, Training Loss= 0.000709
# epoch 21, Training Loss= 0.000707
# epoch 31, Training Loss= 0.000707
# epoch 41, Training Loss= 0.000701
# epoch 51, Training Loss= 0.000700
# epoch 61, Training Loss= 0.000731
# epoch 71, Training Loss= 0.000699
# epoch 81, Training Loss= 0.000680
# epoch 91, Training Loss= 0.000698
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 30.5219271478
# ('epsilon is', 31.964099155868674)
# test starts
# mean value of real cost is 25.8100933207
# mean value of real cost is 32.2128488269
# mean value of real cost is 32.1892536087
# iteration =  6
# trajectory optimization start!!
# (0, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 50.5762967688
# mean value of real cost is 42.0067551221
# mean value of real cost is 50.1964635582
# mean value of real cost is 56.2081546723
# mean value of real cost is 55.3660804189
# mean value of real cost is 53.4273187033
# mean value of real cost is 53.7786452518
# mean value of real cost is 44.6705774475
# mean value of real cost is 51.1024761231
# mean value of real cost is 51.9922545813
# mean value of real cost is 46.0040075566
# mean value of real cost is 54.3685608498
# mean value of real cost is 50.3431538505
# mean value of real cost is 53.0242438381
# mean value of real cost is 48.9646093353
# mean value of real cost is 52.7667762148
# mean value of real cost is 43.1677649564
# mean value of real cost is 52.6810790291
# mean value of real cost is 46.4184588517
# mean value of real cost is 49.1279636911
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 1)
# SUCCEESS: cost change < tolFun
# ('cost = ', 25.94245659419758, 'KL = ', 1.5567145338077442, 'epsilon = ', 31.964099155868674)
# ('KL < epsilon // eta = ', 0.10000000000000001)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.877797031831943, 'KL = ', 50.637377689094123, 'epsilon = ', 31.964099155868674)
# ('PD is not satisfied // eta = ', 0.31622776601683794)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.908772935875703, 'KL = ', 10.913929561574976, 'epsilon = ', 31.964099155868674)
# ('KL < epsilon // eta = ', 0.17782794100389229)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 25.89122070928649, 'KL = ', 24.998649503417173, 'epsilon = ', 31.964099155868674)
# ('KL < epsilon // eta = ', 0.1333521432163324)
# SUCCEESS: cost change < tolFun
# ('cost = ', 25.883847689392365, 'KL = ', 36.150077895956677, 'epsilon = ', 31.964099155868674)
# ('PD is not satisfied // eta = ', 0.15399265260594922)
# SUCCEESS: cost change < tolFun
# ('cost = ', 25.887380044740819, 'KL = ', 30.180675836698441, 'epsilon = ', 31.964099155868674)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.15399265260594922)
# (1, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 62.7568404083
# mean value of real cost is 56.2768715632
# mean value of real cost is 60.7926127079
# mean value of real cost is 65.7002469131
# mean value of real cost is 54.7400475585
# mean value of real cost is 59.2749939388
# mean value of real cost is 48.6076337396
# mean value of real cost is 58.6509458651
# mean value of real cost is 57.5700918281
# mean value of real cost is 51.2898114064
# mean value of real cost is 59.1369169154
# mean value of real cost is 54.395932257
# mean value of real cost is 52.2211163159
# mean value of real cost is 60.9749697702
# mean value of real cost is 56.1907824259
# mean value of real cost is 59.6770472868
# mean value of real cost is 64.9824418825
# mean value of real cost is 51.0169426211
# mean value of real cost is 66.4760655051
# mean value of real cost is 50.5642073867
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.15399265260594922)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.236226237000757, 'KL = ', 30.238354152704645, 'epsilon = ', 31.964099155868674)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.15399265260594922)
# (2, 'initial position in trajectory optimization')
# move the robot !!
# mean value of real cost is 59.7320227949
# mean value of real cost is 61.6634096374
# mean value of real cost is 59.0151337669
# mean value of real cost is 52.5472118549
# mean value of real cost is 58.1839872164
# mean value of real cost is 56.0649207697
# mean value of real cost is 54.9744666383
# mean value of real cost is 63.094964329
# mean value of real cost is 50.3111575127
# mean value of real cost is 57.5547958125
# mean value of real cost is 57.608623614
# mean value of real cost is 59.5587534648
# mean value of real cost is 65.4728580842
# mean value of real cost is 54.5170112842
# mean value of real cost is 54.3607201942
# mean value of real cost is 56.8440360901
# mean value of real cost is 60.9121511772
# mean value of real cost is 64.624240537
# mean value of real cost is 53.9067488355
# mean value of real cost is 51.6152642731
# fit the local model !!
# fit the approximated global model !!
# fit linearized global policy
# ('DGD starts!! eta = ', 0.15399265260594922)
# SUCCEESS : gradient norm < tolGrad
# ('cost = ', 32.263571228558774, 'KL = ', 30.253737739162545, 'epsilon = ', 31.964099155868674)
# =================== dual gradient descent is converged ===================
# ('eta = ', 0.15399265260594922)
# trajectory optimization is finished Traj estimated cost is 30.1303078355
# policy optimization start!!
# epoch 1, Training Loss= 0.000532
# epoch 11, Training Loss= 0.000471
# epoch 21, Training Loss= 0.000469
# epoch 31, Training Loss= 0.000453
# epoch 41, Training Loss= 0.000469
# epoch 51, Training Loss= 0.000449
# epoch 61, Training Loss= 0.000450
# epoch 71, Training Loss= 0.000467
# epoch 81, Training Loss= 0.000451
# epoch 91, Training Loss= 0.000462
# Optimization - policy mean is done
# Optimization - policy variance is done
# policy optimization is finished NN estimated cost is 30.2264238192
# ('epsilon is', 65.11798581213958)
# test starts
# mean value of real cost is 25.7423359378
# mean value of real cost is 32.1237717464
# mean value of real cost is 32.1143839371
# SUCCEESS : cost change < tolFun

# %%
# i=4
np.savetxt('w1.txt',W1_save[i,:,:])
np.savetxt('w2.txt',W2_save[i,:,:])
np.savetxt('w3.txt',W3_save[i,:,:])
np.savetxt('b1.txt',b1_save[i,:])
np.savetxt('b2.txt',b2_save[i,:])
np.savetxt('b3.txt',b3_save[i,:])
# np.savetxt('var.txt',var_save[i,:,:])
